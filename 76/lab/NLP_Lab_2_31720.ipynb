# %% [markdown]
# # <center> NLP Lab 2 </center>

# %% [markdown]
# # Introduction to NLP with NLTK

# %% [markdown]
# Natural Language Processing (NLP) is often taught at the academic level from the perspective of computational linguists. However, as data scientists, we have a richer view of the natural language world - unstructured data that by its very nature has latent information that is important to humans. NLP practioners have benefited from machine learning techniques to unlock meaning from large corpora, and in this class we’ll explore how to do that particularly with Python and with the Natural Language Toolkit (NLTK).
#
# NLTK is an excellent library for machine-learning based NLP, written in Python by experts from both academia and industry. Python allows you to create rich data applications rapidly, iterating on hypotheses. The combination of Python + NLTK means that you can easily add language-aware data products to your larger analytical workflows and applications.
#
# ## Quick Overview of NLTK
# NLTK stands for the Natural Language Toolkit and is written by two eminent computational linguists, Steven Bird (Senior Research Associate of the LDC and professor at the University of Melbourne) and Ewan Klein (Professor of Linguistics at Edinburgh University). NTLK provides a combination of natural language corpora, lexical resources, and example grammars with language processing algorithms, methodologies and demonstrations for a very pythonic "batteries included" view of Natural Language Processing.
#
# As such, NLTK is perfect for researh driven (hypothesis driven) workflows for agile data science. Its suite of libraries includes:
#
# - tokenization, stemming, and tagging
# - chunking and parsing
# - language modeling
# - classification and clustering
# - logical semantics
#
# ## Installing NLTK
#
# This notebook has a few dependencies, most of which can be installed via the python package manger - `pip`.
#
# 1. Python 3.6 or later (anaconda is ok)
# 2. NLTK
# 3. The NLTK corpora
#
#
# Once you have Python and pip installed you can install NLTK as follows:
#
#     ~$ pip install nltk

# %%
import nltk

# %% [markdown]
# ## Working with Example Corpora
#
# NLTK ships with a variety of corpora, let's use a few of them to do some work. Project "gutenberg" has dataset of 25000 books. 18 of those books are available within nltk as nltk.corpus.gutenberg. Download could be called as follows:

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /usr/lib/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg

# %% [markdown]
# ## Getting Names of all 18 books

# %%
file_names = gutenberg.fileids()
print(file_names)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %% [markdown]
# ## Create a dictionary of term frequencies for ALL FILES

# %%
term_frequency = {}
for book_name in file_names:
    for word in gutenberg.words(book_name):
        if term_frequency.__contains__(word):
            term_frequency[word] = term_frequency[word] + 1
        else:
            term_frequency[word] = 1

# %%
term_frequency
# Out:
# {'[': 115,
#  'Emma': 866,
#  'by': 8012,
#  'Jane': 303,
#  'Austen': 3,
#  '1816': 1,
#  ']': 105,
#  'VOLUME': 3,
#  'I': 30221,
#  'CHAPTER': 291,
#  'Woodhouse': 313,
#  ',': 186091,
#  'handsome': 130,
#  'clever': 74,
#  'and': 78846,
#  'rich': 231,
#  'with': 16827,
#  'a': 32504,
#  'comfortable': 108,
#  'home': 677,
#  'happy': 537,
#  'disposition': 73,
#  'seemed': 1083,
#  'to': 46443,
#  'unite': 17,
#  'some': 2560,
#  'of': 70078,
#  'the': 125748,
#  'best': 574,
#  'blessings': 24,
#  'existence': 47,
#  ';': 27329,
#  'had': 10177,
#  'lived': 260,
#  'nearly': 137,
#  'twenty': 459,
#  '-': 8850,
#  'one': 5755,
#  'years': 1011,
#  'in': 31959,
#  'world': 1222,
#  'very': 3852,
#  'little': 2825,
#  'distress': 111,
#  'or': 5901,
#  'vex': 24,
#  'her': 11153,
#  '.': 73746,
#  'She': 1612,
#  'was': 18558,
#  'youngest': 42,
#  'two': 2268,
#  'daughters': 319,
#  'most': 1457,
#  'affectionate': 56,
#  'indulgent': 11,
#  'father': 1673,
#  'consequence': 132,
#  'sister': 592,
#  "'": 19873,
#  's': 9792,
#  'marriage': 142,
#  'been': 3408,
#  'mistress': 137,
#  'his': 20585,
#  'house': 2850,
#  'from': 8647,
#  'early': 277,
#  'period': 64,
#  'Her': 366,
#  'mother': 1124,
#  'died': 299,
#  'too': 1460,
#  'long': 1690,
#  'ago': 191,
#  'for': 16860,
#  'have': 9900,
#  'more': 3978,
#  'than': 2871,
#  'an': 4730,
#  'indistinct': 4,
#  'remembrance': 90,
#  'caresses': 7,
#  'place': 1545,
#  'supplied': 34,
#  'excellent': 164,
#  'woman': 932,
#  'as': 13335,
#  'governess': 17,
#  'who': 3605,
#  'fallen': 205,
#  'short': 393,
#  'affection': 163,
#  'Sixteen': 5,
#  'Miss': 1127,
#  'Taylor': 52,
#  'Mr': 2350,
#  'family': 478,
#  'less': 471,
#  'friend': 706,
#  'fond': 153,
#  'both': 988,
#  'but': 9252,
#  'particularly': 136,
#  'Between': 22,
#  '_them_': 4,
#  'it': 19734,
#  'intimacy': 46,
#  'sisters': 151,
#  'Even': 183,
#  'before': 3335,
#  'ceased': 77,
#  'hold': 507,
#  'nominal': 4,
#  'office': 111,
#  'mildness': 16,
#  'temper': 135,
#  'hardly': 303,
#  'allowed': 104,
#  'impose': 13,
#  'any': 3328,
#  'restraint': 22,
#  'shadow': 154,
#  'authority': 88,
#  'being': 1618,
#  'now': 3397,
#  'passed': 504,
#  'away': 1987,
#  'they': 11536,
#  'living': 423,
#  'together': 958,
#  'mutually': 8,
#  'attached': 74,
#  'doing': 262,
#  'just': 1202,
#  'what': 4133,
#  'she': 7434,
#  'liked': 100,
#  'highly': 97,
#  'esteeming': 2,
#  'judgment': 373,
#  'directed': 33,
#  'chiefly': 53,
#  'own': 2218,
#  'The': 7542,
#  'real': 258,
#  'evils': 38,
#  'indeed': 757,
#  'situation': 169,
#  'were': 6814,
#  'power': 574,
#  'having': 692,
#  'rather': 792,
#  'much': 2268,
#  'way': 1913,
#  'think': 1654,
#  'well': 1925,
#  'herself': 968,
#  'these': 2400,
#  'disadvantages': 3,
#  'which': 8435,
#  'threatened': 21,
#  'alloy': 7,
#  'many': 1520,
#  'enjoyments': 10,
#  'danger': 144,
#  'however': 584,
#  'at': 8642,
#  'present': 595,
#  'so': 6338,
#  'unperceived': 6,
#  'that': 27289,
#  'did': 2913,
#  'not': 16834,
#  'means': 290,
#  'rank': 61,
#  'misfortunes': 6,
#  'Sorrow': 7,
#  'came': 3313,
#  '--': 5445,
#  'gentle': 107,
#  'sorrow': 161,
#  'all': 12965,
#  'shape': 158,
#  'disagreeable': 34,
#  'consciousness': 56,
#  '.--': 920,
#  'married': 180,
#  'It': 2558,
#  'loss': 114,
#  'first': 1844,
#  'brought': 1225,
#  'grief': 65,
#  'on': 8194,
#  'wedding': 40,
#  'day': 3280,
#  'this': 7706,
#  'beloved': 142,
#  'sat': 554,
#  'mournful': 12,
#  'thought': 1339,
#  'continuance': 17,
#  'over': 2495,
#  'bride': 42,
#  'people': 2773,
#  'gone': 698,
#  'left': 1011,
#  'dine': 45,
#  'no': 4910,
#  'prospect': 58,
#  'third': 311,
#  'cheer': 35,
#  'evening': 486,
#  'composed': 36,
#  'himself': 1697,
#  'sleep': 284,
#  'after': 2419,
#  'dinner': 190,
#  'usual': 186,
#  'then': 2907,
#  'only': 2372,
#  'sit': 306,
#  'lost': 343,
#  'event': 92,
#  'every': 2710,
#  'promise': 199,
#  'happiness': 230,
#  'Weston': 439,
#  'man': 5372,
#  'unexceptionable': 8,
#  'character': 213,
#  'easy': 163,
#  'fortune': 150,
#  'suitable': 14,
#  'age': 208,
#  'pleasant': 193,
#  'manners': 158,
#  'there': 5225,
#  'satisfaction': 106,
#  'considering': 80,
#  'self': 174,
#  'denying': 23,
#  'generous': 58,
#  'friendship': 102,
#  'always': 987,
#  'wished': 183,
#  'promoted': 12,
#  'match': 92,
#  'black': 450,
#  'morning': 863,
#  'work': 880,
#  'want': 538,
#  'would': 3932,
#  'be': 15844,
#  'felt': 604,
#  'hour': 454,
#  'recalled': 21,
#  'past': 317,
#  'kindness': 167,
#  'sixteen': 40,
#  'how': 1857,
#  'taught': 174,
#  'played': 66,
#  'five': 564,
#  'old': 1911,
#  'devoted': 30,
#  'powers': 69,
#  'attach': 18,
#  'amuse': 18,
#  'health': 155,
#  'nursed': 7,
#  'through': 1482,
#  'various': 99,
#  'illnesses': 3,
#  'childhood': 22,
#  'A': 1456,
#  'large': 431,
#  'debt': 25,
#  'gratitude': 80,
#  'owing': 33,
#  'here': 1439,
#  'intercourse': 32,
#  'last': 1305,
#  'seven': 535,
#  'equal': 205,
#  'footing': 10,
#  'perfect': 286,
#  'unreserve': 10,
#  'soon': 1027,
#  'followed': 301,
#  'Isabella': 93,
#  'their': 7516,
#  'each': 743,
#  'other': 2421,
#  'yet': 1867,
#  'dearer': 12,
#  'tenderer': 2,
#  'recollection': 48,
#  'companion': 139,
#  'such': 2347,
#  'few': 657,
#  'possessed': 63,
#  ':': 47406,
#  'intelligent': 25,
#  'informed': 50,
#  'useful': 60,
#  'knowing': 152,
#  'ways': 309,
#  'interested': 45,
#  'its': 1261,
#  'concerns': 29,
#  'peculiarly': 24,
#  'pleasure': 411,
#  'scheme': 69,
#  'hers': 60,
#  'whom': 1345,
#  'could': 3528,
#  'speak': 911,
#  'arose': 212,
#  'never': 1765,
#  'find': 720,
#  'fault': 96,
#  'How': 853,
#  'bear': 438,
#  'change': 270,
#  '?--': 371,
#  'true': 469,
#  'going': 776,
#  'half': 868,
#  'mile': 64,
#  'them': 10218,
#  'aware': 84,
#  'great': 2769,
#  'must': 2274,
#  'difference': 147,
#  'between': 744,
#  'Mrs': 1851,
#  'advantages': 37,
#  'natural': 213,
#  'domestic': 46,
#  'suffering': 80,
#  'intellectual': 38,
#  'solitude': 39,
#  'dearly': 21,
#  'loved': 234,
#  'he': 22198,
#  'He': 3636,
#  'meet': 363,
#  'conversation': 186,
#  'rational': 45,
#  'playful': 9,
#  'evil': 801,
#  'actual': 27,
#  'disparity': 10,
#  'ages': 63,
#  '(': 1761,
#  ')': 456,
#  'increased': 112,
#  'constitution': 13,
#  'habits': 50,
#  'valetudinarian': 1,
#  'life': 1380,
#  'without': 1530,
#  'activity': 27,
#  'mind': 751,
#  'body': 753,
#  'older': 36,
#  'though': 1498,
#  'everywhere': 48,
#  'friendliness': 11,
#  'heart': 1481,
#  'amiable': 74,
#  'talents': 73,
#  'recommended': 30,
#  'him': 12924,
#  'time': 2635,
#  'comparatively': 36,
#  'removed': 155,
#  'matrimony': 10,
#  'settled': 152,
#  'London': 170,
#  'miles': 126,
#  'off': 1552,
#  'beyond': 320,
#  'daily': 118,
#  'reach': 116,
#  'October': 11,
#  'November': 21,
#  'struggled': 14,
#  'Hartfield': 160,
#  'Christmas': 53,
#  'next': 532,
#  'visit': 273,
#  'husband': 308,
#  'children': 2223,
#  'fill': 168,
#  'give': 1669,
#  'society': 133,
#  'again': 2028,
#  'Highbury': 125,
#  'populous': 19,
#  'village': 129,
#  'almost': 725,
#  'amounting': 4,
#  'town': 257,
#  'spite': 131,
#  'separate': 105,
#  'lawn': 30,
#  'shrubberies': 7,
#  'name': 1481,
#  'really': 656,
#  'belong': 77,
#  'afforded': 25,
#  'equals': 14,
#  'Woodhouses': 4,
#  'All': 738,
#  'looked': 983,
#  'up': 4955,
#  'acquaintance': 217,
#  'universally': 15,
#  'civil': 56,
#  'among': 1336,
#  'accepted': 69,
#  'lieu': 3,
#  'even': 2292,
#  'melancholy': 67,
#  'sigh': 83,
#  'wish': 493,
#  'impossible': 164,
#  'things': 1953,
#  'till': 908,
#  'awoke': 20,
#  'made': 2728,
#  'necessary': 149,
#  'cheerful': 96,
#  'His': 785,
#  'spirits': 270,
#  'required': 78,
#  'support': 57,
#  'nervous': 40,
#  'easily': 132,
#  'depressed': 11,
#  'used': 309,
#  'hating': 9,
#  'part': 838,
#  'kind': 472,
#  'Matrimony': 1,
#  'origin': 19,
#  'reconciled': 28,
#  'daughter': 552,
#  'marrying': 50,
#  'nor': 1466,
#  'ever': 1617,
#  'compassion': 87,
#  'entirely': 189,
#  'when': 5287,
#  'obliged': 222,
#  'selfishness': 20,
#  'able': 399,
#  'suppose': 340,
#  'feel': 425,
#  'differently': 30,
#  'disposed': 84,
#  'done': 1317,
#  'sad': 142,
#  'thing': 1966,
#  'deal': 333,
#  'happier': 46,
#  'if': 3964,
#  'spent': 129,
#  'rest': 748,
#  'smiled': 98,
#  'chatted': 2,
#  'cheerfully': 26,
#  'keep': 678,
#  'thoughts': 310,
#  'tea': 84,
#  'say': 2642,
#  'exactly': 208,
#  'said': 9410,
#  '"': 15422,
#  'Poor': 99,
#  '!--': 744,
#  'What': 1646,
#  'pity': 144,
#  'is': 15944,
#  '!"': 1719,
#  'cannot': 799,
#  'agree': 54,
#  'you': 14648,
#  'papa': 83,
#  'know': 2996,
#  'good': 2702,
#  'humoured': 35,
#  'thoroughly': 56,
#  'deserves': 22,
#  'wife': 713,
#  ';--': 348,
#  'live': 536,
#  'us': 2788,
#  'my': 9580,
#  'odd': 97,
#  'humours': 9,
#  'might': 1938,
#  '?"': 2285,
#  'But': 4685,
#  'where': 1460,
#  'advantage': 116,
#  '?': 7342,
#  'This': 1186,
#  'three': 1179,
#  'times': 459,
#  'And': 16533,
#  'dear': 654,
#  '."': 5751,
#  'often': 410,
#  'we': 4213,
#  'shall': 11456,
#  'see': 2746,
#  'coming': 509,
#  'We': 913,
#  'meeting': 153,
#  '!': 5730,
#  '_We_': 2,
#  'begin': 167,
#  'go': 2517,
#  'pay': 208,
#  'My': 892,
#  'am': 2925,
#  'get': 681,
#  'far': 893,
#  'Randalls': 90,
#  'distance': 162,
#  'walk': 488,
#  'No': 921,
#  'nobody': 178,
#  'your': 4842,
#  'walking': 218,
#  'carriage': 192,
#  'sure': 899,
#  'James': 106,
#  'will': 7130,
#  'like': 3354,
#  'put': 1528,
#  'horses': 238,
#  'are': 6642,
#  'poor': 805,
#  'while': 1046,
#  'paying': 34,
#  'our': 2508,
#  'They': 1559,
#  'into': 4031,
#  'stable': 39,
#  'You': 1670,
#  'already': 299,
#  'talked': 223,
#  'night': 1165,
#  'may': 2435,
#  'because': 1619,
#  'housemaid': 4,
#  'doubt': 351,
#  'whether': 538,
#  'take': 1552,
#  'anywhere': 71,
#  'else': 541,
#  'That': 1409,
#  'got': 491,
#  'Hannah': 15,
#  'Nobody': 44,
#  'mentioned': 105,
#  'glad': 360,
#  'lucky': 55,
#  'slighted': 16,
#  'upon': 4467,
#  'account': 253,
#  'make': 2166,
#  'servant': 601,
#  'pretty': 272,
#  'spoken': 415,
#  'girl': 281,
#  'opinion': 216,
#  'Whenever': 23,
#  'curtseys': 1,
#  'asks': 10,
#  'me': 9376,
#  'do': 4250,
#  'manner': 509,
#  'needlework': 10,
#  'observe': 132,
#  'turns': 92,
#  'lock': 41,
#  'door': 757,
#  'right': 1070,
#  'bangs': 1,
#  'comfort': 255,
#  'somebody': 70,
#  'about': 2530,
#  'goes': 181,
#  'hearing': 166,
#  'tell': 1058,
#  'spared': 39,
#  'exertions': 19,
#  'maintain': 24,
#  'flow': 60,
#  'ideas': 55,
#  'hoped': 107,
#  'help': 415,
#  'backgammon': 3,
#  'tolerably': 35,
#  'attacked': 13,
#  'regrets': 16,
#  'table': 381,
#  'placed': 129,
#  'visitor': 22,
#  'immediately': 326,
#  'afterwards': 231,
#  'walked': 365,
#  'unnecessary': 36,
#  'Knightley': 389,
#  'sensible': 95,
#  'eight': 168,
#  'thirty': 253,
#  'intimate': 40,
#  'connected': 52,
#  'elder': 50,
#  'brother': 752,
#  'frequent': 42,
#  'welcome': 134,
#  'directly': 164,
#  'mutual': 44,
#  'connexions': 18,
#  'returned': 408,
#  'late': 246,
#  'days': 1258,
#  'absence': 66,
#  'Brunswick': 11,
#  'Square': 31,
#  'circumstance': 115,
#  'animated': 25,
#  'inquiries': 33,
#  'answered': 804,
#  'satisfactorily': 3,
#  'When': 1041,
#  'gratefully': 16,
#  'observed': 146,
#  'come': 3220,
#  'out': 5651,
#  'call': 618,
#  'afraid': 495,
#  'shocking': 32,
#  'Not': 502,
#  'sir': 502,
#  'beautiful': 253,
#  'moonlight': 36,
#  'mild': 70,
#  'draw': 163,
#  'back': 1095,
#  'fire': 879,
#  'found': 1252,
#  'damp': 31,
#  'dirty': 36,
#  'catch': 138,
#  'cold': 271,
#  'Dirty': 1,
#  'Look': 147,
#  'shoes': 80,
#  'speck': 4,
#  'Well': 579,
#  'quite': 1031,
#  'surprising': 17,
#  'vast': 180,
#  'rain': 193,
#  'rained': 16,
#  'dreadfully': 25,
#  'hard': 333,
#  'breakfast': 126,
#  'wanted': 272,
#  'By': 483,
#  'bye': 56,
#  'joy': 424,
#  'Being': 33,
#  'sort': 590,
#  'feeling': 207,
#  'hurry': 125,
#  'congratulations': 9,
#  'hope': 666,
#  'went': 2303,
#  'behave': 23,
#  'Who': 651,
#  'cried': 1106,
#  'Ah': 181,
#  'Tis': 79,
#  'business': 369,
#  'please': 285,
#  'possibly': 91,
#  '`': 176,
#  ".'": 327,
#  'regard': 182,
#  'comes': 293,
#  'question': 254,
#  'dependence': 24,
#  'independence': 27,
#  'At': 517,
#  'rate': 93,
#  'better': 836,
#  'Especially': 2,
#  '_one_': 6,
#  'those': 1557,
#  'fanciful': 14,
#  'troublesome': 21,
#  'creature': 182,
#  'playfully': 6,
#  'head': 1450,
#  'certainly': 353,
#  'believe': 644,
#  ',"': 4702,
#  'sometimes': 253,
#  'dearest': 52,
#  'mean': 547,
#  '_you_': 18,
#  'horrible': 70,
#  'idea': 294,
#  'Oh': 970,
#  'meant': 203,
#  'myself': 776,
#  'loves': 49,
#  'joke': 38,
#  'another': 1195,
#  'fact': 226,
#  'faults': 38,
#  'told': 776,
#  'agreeable': 120,
#  'knew': 742,
#  'suspect': 65,
#  'knows': 180,
#  'flatter': 21,
#  'reflection': 59,
#  'has': 1600,
#  'persons': 144,
#  'chances': 22,
#  'gainer': 3,
#  'willing': 92,
#  'let': 1905,
#  'pass': 1072,
#  '--"': 483,
#  'hear': 1109,
#  'behaved': 41,
#  'charmingly': 5,
#  'Every': 182,
#  'punctual': 10,
#  'looks': 192,
#  'tear': 53,
#  'face': 1264,
#  'seen': 925,
#  'apart': 59,
#  'Dear': 68,
#  'bears': 26,
#  'sorry': 214,
#  'lose': 114,
#  '_will_': 3,
#  'miss': 60,
#  'thinks': 86,
#  'turned': 724,
#  'divided': 116,
#  'tears': 177,
#  'smiles': 59,
#  'should': 2496,
#  'acceptable': 39,
#  'important': 113,
#  'secure': 98,
#  'provision': 22,
#  'therefore': 1146,
#  'allow': 117,
#  'pain': 197,
#  'happily': 40,
#  'forgotten': 154,
#  'matter': 491,
#  'considerable': 98,
#  'four': 602,
#  'proved': 98,
#  'marry': 157,
#  'shook': 102,
#  'fondly': 15,
#  'replied': 481,
#  'matches': 10,
#  'foretell': 5,
#  'whatever': 183,
#  'Pray': 84,
#  'none': 633,
#  'greatest': 147,
#  'amusement': 54,
#  'success': 70,
#  'widower': 6,
#  'perfectly': 238,
#  'constantly': 38,
#  'occupied': 57,
#  'either': 357,
#  'friends': 436,
#  'wherever': 49,
#  'need': 278,
#  'spend': 76,
#  'single': 131,
#  'year': 606,
#  'alone': 476,
#  'Some': 192,
#  'deathbed': 2,
#  'others': 473,
#  'son': 2393,
#  'uncle': 111,
#  'letting': 24,
#  'solemn': 107,
#  'nonsense': 57,
#  'subject': 266,
#  'believed': 246,
#  'Ever': 38,
#  'since': 490,
#  'met': 238,
#  'Broadway': 10,
#  'Lane': 11,
#  'began': 753,
#  'drizzle': 1,
#  'darted': 49,
#  'gallantry': 22,
#  'borrowed': 18,
#  'umbrellas': 4,
#  'Farmer': 137,
#  'Mitchell': 1,
#  'planned': 10,
#  'blessed': 228,
#  'instance': 66,
#  'leave': 493,
#  'making': 325,
#  'understand': 415,
#  ',\'"': 5,
#  'Success': 1,
#  'supposes': 5,
#  'endeavour': 27,
#  'Your': 261,
#  'properly': 56,
#  'delicately': 8,
#  'endeavouring': 19,
#  'bring': 933,
#  'worthy': 151,
#  'employment': 37,
#  'young': 1135,
#  'lady': 327,
#  'imagine': 123,
#  'planning': 8,
#  'saying': 1685,
#  'yourself': 289,
#  'idle': 79,
#  ",'": 530,
#  'why': 565,
#  'talk': 336,
#  'Where': 391,
#  'merit': 52,
#  'proud': 175,
#  'guess': 114,
#  '_that_': 12,
#  'can': 2163,
#  'known': 614,
#  'triumph': 65,
#  'cleverer': 5,
#  'depend': 48,
#  'merely': 169,
#  'luck': 71,
#  'There': 1143,
#  'talent': 26,
#  'word': 1286,
#  'quarrel': 55,
#  'claim': 49,
#  'drawn': 135,
#  'pictures': 40,
#  'something': 881,
#  'nothing': 1339,
#  'If': 1271,
#  'visits': 38,
#  'given': 843,
#  'encouragements': 2,
#  'smoothed': 6,
#  'matters': 89,
#  'enough': 795,
#  'comprehend': 53,
#  'straightforward': 4,
#  'open': 538,
#  'hearted': 57,
#  'unaffected': 14,
#  'safely': 85,
#  'manage': 31,
#  'likely': 153,
#  'harm': 90,
#  'interference': 18,
#  'rejoined': 11,
#  'understanding': 239,
#  'pray': 442,
#  'silly': 64,
#  'break': 255,
#  'circle': 89,
#  'grievously': 8,
#  'Only': 131,
#  'Elton': 385,
#  ',--': 341,
#  'look': 1037,
#  'whole': 936,
#  'fitted': 37,
#  'comfortably': 31,
#  'shame': 201,
#  'longer': 306,
#  'joining': 15,
#  'hands': 994,
#  'same': 1265,
#  'service': 222,
#  'shew': 302,
#  'attention': 200,
#  'ask': 405,
#  'dare': 199,
#  'With': 762,
#  'laughing': 144,
#  'Invite': 2,
#  'fish': 293,
#  'chicken': 8,
#  'chuse': 30,
#  'Depend': 18,
#  'six': 346,
#  'care': 295,
#  'II': 38,
#  'native': 62,
#  'born': 296,
#  'respectable': 59,
#  'generations': 138,
#  'rising': 181,
#  'gentility': 9,
#  'property': 58,
#  'received': 364,
#  'education': 55,
#  'succeeding': 19,
#  'small': 554,
#  'become': 318,
#  'indisposed': 8,
#  'homely': 10,
#  'pursuits': 17,
#  'brothers': 60,
#  'engaged': 139,
#  'satisfied': 194,
#  'active': 50,
#  'social': 42,
#  'entering': 84,
#  'militia': 7,
#  'county': 19,
#  'embodied': 5,
#  'Captain': 555,
#  'general': 268,
#  'favourite': 105,
#  'military': 29,
#  'introduced': 46,
#  'Churchill': 241,
#  'Yorkshire': 10,
#  'fell': 528,
#  'love': 1063,
#  'surprized': 33,
#  'except': 268,
#  'full': 795,
#  'pride': 168,
#  'importance': 68,
#  'connexion': 41,
#  'offend': 54,
#  'command': 241,
#  'bore': 73,
#  'proportion': 29,
#  'estate': 64,
#  'dissuaded': 1,
#  'took': 1237,
#  'infinite': 57,
#  'mortification': 22,
#  'threw': 109,
#  'due': 145,
#  'decorum': 10,
#  'unsuitable': 5,
#  'produce': 52,
#  'ought': 381,
#  'whose': 730,
#  'warm': 139,
#  'sweet': 379,
#  'return': 532,
#  'goodness': 110,
#  'spirit': 505,
#  'resolution': 84,
#  'pursue': 48,
#  'refrain': 23,
#  'unreasonable': 22,
#  'anger': 307,
#  'missing': 32,
#  'luxuries': 4,
#  'former': 174,
#  'income': 42,
#  'still': 1279,
#  'comparison': 48,
#  'Enscombe': 36,
#  'cease': 110,
#  'once': 862,
#  ...}

# %% [markdown]
# ## Create an Inverted index containing document-wise frequency

# %%
inverted_index = {}
for book_name in file_names:
    for word in gutenberg.words(book_name):
        if inverted_index.__contains__(word):
            posting_list = inverted_index[word]
            if posting_list.__contains__(book_name):
                posting_list[book_name] = posting_list[book_name] + 1
            else:
                posting_list[book_name] = 1
        else:
            inverted_index[word] = {book_name:1}

# %%
inverted_index
# Out:
# {'[': {'austen-emma.txt': 2,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 3,
#   'bible-kjv.txt': 1,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 4,
#   'burgess-busterbrown.txt': 6,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 11,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 6,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 2,
#   'shakespeare-caesar.txt': 3,
#   'shakespeare-hamlet.txt': 6,
#   'shakespeare-macbeth.txt': 4,
#   'whitman-leaves.txt': 57},
#  'Emma': {'austen-emma.txt': 865, 'austen-persuasion.txt': 1},
#  'by': {'austen-emma.txt': 558,
#   'austen-persuasion.txt': 411,
#   'austen-sense.txt': 737,
#   'bible-kjv.txt': 2540,
#   'blake-poems.txt': 21,
#   'bryant-stories.txt': 91,
#   'burgess-busterbrown.txt': 23,
#   'carroll-alice.txt': 55,
#   'chesterton-ball.txt': 279,
#   'chesterton-brown.txt': 259,
#   'chesterton-thursday.txt': 172,
#   'edgeworth-parents.txt': 703,
#   'melville-moby_dick.txt': 1137,
#   'milton-paradise.txt': 380,
#   'shakespeare-caesar.txt': 82,
#   'shakespeare-hamlet.txt': 91,
#   'shakespeare-macbeth.txt': 36,
#   'whitman-leaves.txt': 437},
#  'Jane': {'austen-emma.txt': 301,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1},
#  'Austen': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1},
#  '1816': {'austen-emma.txt': 1},
#  ']': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 1,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 4,
#   'burgess-busterbrown.txt': 5,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 10,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 1,
#   'milton-paradise.txt': 1,
#   'shakespeare-caesar.txt': 3,
#   'shakespeare-hamlet.txt': 3,
#   'shakespeare-macbeth.txt': 4,
#   'whitman-leaves.txt': 64},
#  'VOLUME': {'austen-emma.txt': 3},
#  'I': {'austen-emma.txt': 3178,
#   'austen-persuasion.txt': 1124,
#   'austen-sense.txt': 2004,
#   'bible-kjv.txt': 8854,
#   'blake-poems.txt': 130,
#   'bryant-stories.txt': 536,
#   'burgess-busterbrown.txt': 156,
#   'carroll-alice.txt': 543,
#   'chesterton-ball.txt': 1000,
#   'chesterton-brown.txt': 1093,
#   'chesterton-thursday.txt': 885,
#   'edgeworth-parents.txt': 3656,
#   'melville-moby_dick.txt': 2124,
#   'milton-paradise.txt': 589,
#   'shakespeare-caesar.txt': 531,
#   'shakespeare-hamlet.txt': 553,
#   'shakespeare-macbeth.txt': 333,
#   'whitman-leaves.txt': 2932},
#  'CHAPTER': {'austen-emma.txt': 55,
#   'austen-sense.txt': 50,
#   'carroll-alice.txt': 12,
#   'chesterton-thursday.txt': 15,
#   'edgeworth-parents.txt': 9,
#   'melville-moby_dick.txt': 150},
#  'Woodhouse': {'austen-emma.txt': 313},
#  ',': {'austen-emma.txt': 11454,
#   'austen-persuasion.txt': 6750,
#   'austen-sense.txt': 9397,
#   'bible-kjv.txt': 70509,
#   'blake-poems.txt': 680,
#   'bryant-stories.txt': 3481,
#   'burgess-busterbrown.txt': 822,
#   'carroll-alice.txt': 1993,
#   'chesterton-ball.txt': 4547,
#   'chesterton-brown.txt': 4069,
#   'chesterton-thursday.txt': 3488,
#   'edgeworth-parents.txt': 15219,
#   'melville-moby_dick.txt': 18713,
#   'milton-paradise.txt': 10198,
#   'shakespeare-caesar.txt': 2204,
#   'shakespeare-hamlet.txt': 2892,
#   'shakespeare-macbeth.txt': 1962,
#   'whitman-leaves.txt': 17713},
#  'handsome': {'austen-emma.txt': 37,
#   'austen-persuasion.txt': 19,
#   'austen-sense.txt': 27,
#   'bryant-stories.txt': 2,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 11,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 18,
#   'melville-moby_dick.txt': 3,
#   'whitman-leaves.txt': 7},
#  'clever': {'austen-emma.txt': 27,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 5,
#   'bryant-stories.txt': 4,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 9,
#   'chesterton-thursday.txt': 5,
#   'edgeworth-parents.txt': 12,
#   'melville-moby_dick.txt': 1},
#  'and': {'austen-emma.txt': 4672,
#   'austen-persuasion.txt': 2739,
#   'austen-sense.txt': 3350,
#   'bible-kjv.txt': 38847,
#   'blake-poems.txt': 169,
#   'bryant-stories.txt': 1873,
#   'burgess-busterbrown.txt': 484,
#   'carroll-alice.txt': 802,
#   'chesterton-ball.txt': 2488,
#   'chesterton-brown.txt': 2074,
#   'chesterton-thursday.txt': 1568,
#   'edgeworth-parents.txt': 4769,
#   'melville-moby_dick.txt': 6024,
#   'milton-paradise.txt': 2799,
#   'shakespeare-caesar.txt': 409,
#   'shakespeare-hamlet.txt': 606,
#   'shakespeare-macbeth.txt': 376,
#   'whitman-leaves.txt': 4797},
#  'rich': {'austen-emma.txt': 14,
#   'austen-persuasion.txt': 11,
#   'austen-sense.txt': 16,
#   'bible-kjv.txt': 81,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 10,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 7,
#   'chesterton-brown.txt': 6,
#   'chesterton-thursday.txt': 12,
#   'edgeworth-parents.txt': 26,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 9,
#   'shakespeare-caesar.txt': 2,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 24},
#  'with': {'austen-emma.txt': 1187,
#   'austen-persuasion.txt': 643,
#   'austen-sense.txt': 971,
#   'bible-kjv.txt': 5961,
#   'blake-poems.txt': 59,
#   'bryant-stories.txt': 276,
#   'burgess-busterbrown.txt': 59,
#   'carroll-alice.txt': 175,
#   'chesterton-ball.txt': 799,
#   'chesterton-brown.txt': 726,
#   'chesterton-thursday.txt': 544,
#   'edgeworth-parents.txt': 1304,
#   'melville-moby_dick.txt': 1659,
#   'milton-paradise.txt': 876,
#   'shakespeare-caesar.txt': 131,
#   'shakespeare-hamlet.txt': 212,
#   'shakespeare-macbeth.txt': 134,
#   'whitman-leaves.txt': 1111},
#  'a': {'austen-emma.txt': 3004,
#   'austen-persuasion.txt': 1529,
#   'austen-sense.txt': 2043,
#   'bible-kjv.txt': 7943,
#   'blake-poems.txt': 108,
#   'bryant-stories.txt': 988,
#   'burgess-busterbrown.txt': 275,
#   'carroll-alice.txt': 615,
#   'chesterton-ball.txt': 2184,
#   'chesterton-brown.txt': 2074,
#   'chesterton-thursday.txt': 1713,
#   'edgeworth-parents.txt': 3017,
#   'melville-moby_dick.txt': 4569,
#   'milton-paradise.txt': 442,
#   'shakespeare-caesar.txt': 240,
#   'shakespeare-hamlet.txt': 449,
#   'shakespeare-macbeth.txt': 214,
#   'whitman-leaves.txt': 1097},
#  'comfortable': {'austen-emma.txt': 34,
#   'austen-persuasion.txt': 14,
#   'austen-sense.txt': 30,
#   'bible-kjv.txt': 2,
#   'bryant-stories.txt': 1,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 2,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 4,
#   'melville-moby_dick.txt': 9,
#   'milton-paradise.txt': 1},
#  'home': {'austen-emma.txt': 130,
#   'austen-persuasion.txt': 83,
#   'austen-sense.txt': 69,
#   'bible-kjv.txt': 51,
#   'blake-poems.txt': 4,
#   'bryant-stories.txt': 63,
#   'burgess-busterbrown.txt': 12,
#   'carroll-alice.txt': 5,
#   'chesterton-ball.txt': 12,
#   'chesterton-brown.txt': 17,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 100,
#   'melville-moby_dick.txt': 56,
#   'milton-paradise.txt': 5,
#   'shakespeare-caesar.txt': 12,
#   'shakespeare-hamlet.txt': 6,
#   'shakespeare-macbeth.txt': 5,
#   'whitman-leaves.txt': 43},
#  'happy': {'austen-emma.txt': 122,
#   'austen-persuasion.txt': 63,
#   'austen-sense.txt': 96,
#   'bible-kjv.txt': 17,
#   'blake-poems.txt': 19,
#   'bryant-stories.txt': 24,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 20,
#   'chesterton-brown.txt': 10,
#   'chesterton-thursday.txt': 15,
#   'edgeworth-parents.txt': 52,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 56,
#   'shakespeare-caesar.txt': 3,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 23},
#  'disposition': {'austen-emma.txt': 24,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 21,
#   'bible-kjv.txt': 1,
#   'burgess-busterbrown.txt': 1,
#   'edgeworth-parents.txt': 9,
#   'melville-moby_dick.txt': 3,
#   'shakespeare-hamlet.txt': 5,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 1},
#  'seemed': {'austen-emma.txt': 141,
#   'austen-persuasion.txt': 93,
#   'austen-sense.txt': 91,
#   'bible-kjv.txt': 16,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 14,
#   'burgess-busterbrown.txt': 12,
#   'carroll-alice.txt': 27,
#   'chesterton-ball.txt': 121,
#   'chesterton-brown.txt': 107,
#   'chesterton-thursday.txt': 91,
#   'edgeworth-parents.txt': 30,
#   'melville-moby_dick.txt': 283,
#   'milton-paradise.txt': 55,
#   'whitman-leaves.txt': 1},
#  'to': {'austen-emma.txt': 5183,
#   'austen-persuasion.txt': 2775,
#   'austen-sense.txt': 4063,
#   'bible-kjv.txt': 13396,
#   'blake-poems.txt': 92,
#   'bryant-stories.txt': 1165,
#   'burgess-busterbrown.txt': 426,
#   'carroll-alice.txt': 725,
#   'chesterton-ball.txt': 1558,
#   'chesterton-brown.txt': 1378,
#   'chesterton-thursday.txt': 1045,
#   'edgeworth-parents.txt': 5150,
#   'melville-moby_dick.txt': 4542,
#   'milton-paradise.txt': 1758,
#   'shakespeare-caesar.txt': 370,
#   'shakespeare-hamlet.txt': 576,
#   'shakespeare-macbeth.txt': 311,
#   'whitman-leaves.txt': 1930},
#  'unite': {'austen-emma.txt': 3,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 1,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 3,
#   'whitman-leaves.txt': 3},
#  'some': {'austen-emma.txt': 248,
#   'austen-persuasion.txt': 135,
#   'austen-sense.txt': 206,
#   'bible-kjv.txt': 220,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 51,
#   'burgess-busterbrown.txt': 41,
#   'carroll-alice.txt': 48,
#   'chesterton-ball.txt': 165,
#   'chesterton-brown.txt': 166,
#   'chesterton-thursday.txt': 119,
#   'edgeworth-parents.txt': 284,
#   'melville-moby_dick.txt': 578,
#   'milton-paradise.txt': 70,
#   'shakespeare-caesar.txt': 36,
#   'shakespeare-hamlet.txt': 42,
#   'shakespeare-macbeth.txt': 13,
#   'whitman-leaves.txt': 136},
#  'of': {'austen-emma.txt': 4279,
#   'austen-persuasion.txt': 2564,
#   'austen-sense.txt': 3565,
#   'bible-kjv.txt': 34480,
#   'blake-poems.txt': 131,
#   'bryant-stories.txt': 801,
#   'burgess-busterbrown.txt': 326,
#   'carroll-alice.txt': 500,
#   'chesterton-ball.txt': 2529,
#   'chesterton-brown.txt': 2087,
#   'chesterton-thursday.txt': 1710,
#   'edgeworth-parents.txt': 3730,
#   'melville-moby_dick.txt': 6536,
#   'milton-paradise.txt': 1486,
#   'shakespeare-caesar.txt': 336,
#   'shakespeare-hamlet.txt': 576,
#   'shakespeare-macbeth.txt': 315,
#   'whitman-leaves.txt': 4127},
#  'the': {'austen-emma.txt': 4844,
#   'austen-persuasion.txt': 3120,
#   'austen-sense.txt': 3861,
#   'bible-kjv.txt': 62103,
#   'blake-poems.txt': 351,
#   'bryant-stories.txt': 3086,
#   'burgess-busterbrown.txt': 639,
#   'carroll-alice.txt': 1527,
#   'chesterton-ball.txt': 4523,
#   'chesterton-brown.txt': 4321,
#   'chesterton-thursday.txt': 3291,
#   'edgeworth-parents.txt': 7149,
#   'melville-moby_dick.txt': 13721,
#   'milton-paradise.txt': 2505,
#   'shakespeare-caesar.txt': 502,
#   'shakespeare-hamlet.txt': 860,
#   'shakespeare-macbeth.txt': 531,
#   'whitman-leaves.txt': 8814},
#  'best': {'austen-emma.txt': 85,
#   'austen-persuasion.txt': 44,
#   'austen-sense.txt': 26,
#   'bible-kjv.txt': 25,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 17,
#   'burgess-busterbrown.txt': 9,
#   'carroll-alice.txt': 10,
#   'chesterton-ball.txt': 27,
#   'chesterton-brown.txt': 9,
#   'chesterton-thursday.txt': 11,
#   'edgeworth-parents.txt': 110,
#   'melville-moby_dick.txt': 62,
#   'milton-paradise.txt': 50,
#   'shakespeare-caesar.txt': 12,
#   'shakespeare-hamlet.txt': 10,
#   'shakespeare-macbeth.txt': 7,
#   'whitman-leaves.txt': 59},
#  'blessings': {'austen-emma.txt': 6,
#   'austen-persuasion.txt': 3,
#   'austen-sense.txt': 2,
#   'bible-kjv.txt': 11,
#   'bryant-stories.txt': 1,
#   'whitman-leaves.txt': 1},
#  'existence': {'austen-emma.txt': 8,
#   'austen-persuasion.txt': 3,
#   'austen-sense.txt': 8,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 13,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 1,
#   'melville-moby_dick.txt': 7,
#   'whitman-leaves.txt': 2},
#  ';': {'austen-emma.txt': 2199,
#   'austen-persuasion.txt': 1290,
#   'austen-sense.txt': 1419,
#   'bible-kjv.txt': 10084,
#   'blake-poems.txt': 98,
#   'bryant-stories.txt': 513,
#   'burgess-busterbrown.txt': 10,
#   'carroll-alice.txt': 186,
#   'chesterton-ball.txt': 634,
#   'chesterton-brown.txt': 764,
#   'chesterton-thursday.txt': 331,
#   'edgeworth-parents.txt': 2590,
#   'melville-moby_dick.txt': 4072,
#   'milton-paradise.txt': 2317,
#   'shakespeare-caesar.txt': 106,
#   'shakespeare-hamlet.txt': 298,
#   'shakespeare-macbeth.txt': 52,
#   'whitman-leaves.txt': 366},
#  'had': {'austen-emma.txt': 1606,
#   'austen-persuasion.txt': 1177,
#   'austen-sense.txt': 969,
#   'bible-kjv.txt': 2025,
#   'blake-poems.txt': 6,
#   'bryant-stories.txt': 292,
#   'burgess-busterbrown.txt': 211,
#   'carroll-alice.txt': 177,
#   'chesterton-ball.txt': 556,
#   'chesterton-brown.txt': 521,
#   'chesterton-thursday.txt': 427,
#   'edgeworth-parents.txt': 1163,
#   'melville-moby_dick.txt': 767,
#   'milton-paradise.txt': 149,
#   'shakespeare-caesar.txt': 23,
#   'shakespeare-hamlet.txt': 38,
#   'shakespeare-macbeth.txt': 29,
#   'whitman-leaves.txt': 41},
#  'lived': {'austen-emma.txt': 25,
#   'austen-persuasion.txt': 20,
#   'austen-sense.txt': 20,
#   'bible-kjv.txt': 58,
#   'bryant-stories.txt': 35,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 9,
#   'chesterton-brown.txt': 10,
#   'chesterton-thursday.txt': 5,
#   'edgeworth-parents.txt': 37,
#   'melville-moby_dick.txt': 13,
#   'milton-paradise.txt': 6,
#   'whitman-leaves.txt': 18},
#  'nearly': {'austen-emma.txt': 14,
#   'austen-persuasion.txt': 15,
#   'austen-sense.txt': 8,
#   'bryant-stories.txt': 5,
#   'burgess-busterbrown.txt': 5,
#   'carroll-alice.txt': 10,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 16,
#   'chesterton-thursday.txt': 5,
#   'edgeworth-parents.txt': 18,
#   'melville-moby_dick.txt': 33,
#   'whitman-leaves.txt': 3},
#  'twenty': {'austen-emma.txt': 30,
#   'austen-persuasion.txt': 21,
#   'austen-sense.txt': 15,
#   'bible-kjv.txt': 292,
#   'bryant-stories.txt': 3,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 6,
#   'chesterton-brown.txt': 7,
#   'chesterton-thursday.txt': 13,
#   'edgeworth-parents.txt': 24,
#   'melville-moby_dick.txt': 33,
#   'milton-paradise.txt': 1,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 6},
#  '-': {'austen-emma.txt': 574,
#   'austen-persuasion.txt': 308,
#   'austen-sense.txt': 366,
#   'bible-kjv.txt': 21,
#   'blake-poems.txt': 20,
#   'bryant-stories.txt': 270,
#   'burgess-busterbrown.txt': 74,
#   'carroll-alice.txt': 141,
#   'chesterton-ball.txt': 387,
#   'chesterton-brown.txt': 573,
#   'chesterton-thursday.txt': 294,
#   'edgeworth-parents.txt': 869,
#   'melville-moby_dick.txt': 2552,
#   'milton-paradise.txt': 334,
#   'shakespeare-caesar.txt': 76,
#   'shakespeare-hamlet.txt': 117,
#   'shakespeare-macbeth.txt': 100,
#   'whitman-leaves.txt': 1774},
#  'one': {'austen-emma.txt': 413,
#   'austen-persuasion.txt': 221,
#   'austen-sense.txt': 304,
#   'bible-kjv.txt': 1847,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 156,
#   'burgess-busterbrown.txt': 99,
#   'carroll-alice.txt': 94,
#   'chesterton-ball.txt': 295,
#   'chesterton-brown.txt': 264,
#   'chesterton-thursday.txt': 187,
#   'edgeworth-parents.txt': 462,
#   'melville-moby_dick.txt': 889,
#   'milton-paradise.txt': 114,
#   'shakespeare-caesar.txt': 32,
#   'shakespeare-hamlet.txt': 40,
#   'shakespeare-macbeth.txt': 29,
#   'whitman-leaves.txt': 306},
#  'years': {'austen-emma.txt': 57,
#   'austen-persuasion.txt': 58,
#   'austen-sense.txt': 49,
#   'bible-kjv.txt': 539,
#   'bryant-stories.txt': 22,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 14,
#   'chesterton-brown.txt': 17,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 55,
#   'melville-moby_dick.txt': 94,
#   'milton-paradise.txt': 6,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 92},
#  'in': {'austen-emma.txt': 2118,
#   'austen-persuasion.txt': 1346,
#   'austen-sense.txt': 1904,
#   'bible-kjv.txt': 12331,
#   'blake-poems.txt': 116,
#   'bryant-stories.txt': 607,
#   'burgess-busterbrown.txt': 154,
#   'carroll-alice.txt': 357,
#   'chesterton-ball.txt': 1355,
#   'chesterton-brown.txt': 1205,
#   'chesterton-thursday.txt': 888,
#   'edgeworth-parents.txt': 2129,
#   'melville-moby_dick.txt': 3916,
#   'milton-paradise.txt': 1083,
#   'shakespeare-caesar.txt': 204,
#   'shakespeare-hamlet.txt': 359,
#   'shakespeare-macbeth.txt': 173,
#   'whitman-leaves.txt': 1714},
#  'world': {'austen-emma.txt': 81,
#   'austen-persuasion.txt': 36,
#   'austen-sense.txt': 93,
#   'bible-kjv.txt': 288,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 26,
#   'burgess-busterbrown.txt': 2,
#   'carroll-alice.txt': 7,
#   'chesterton-ball.txt': 111,
#   'chesterton-brown.txt': 15,
#   'chesterton-thursday.txt': 52,
#   'edgeworth-parents.txt': 86,
#   'melville-moby_dick.txt': 173,
#   'milton-paradise.txt': 96,
#   'shakespeare-caesar.txt': 4,
#   'shakespeare-hamlet.txt': 22,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 126},
#  'very': {'austen-emma.txt': 1151,
#   'austen-persuasion.txt': 425,
#   'austen-sense.txt': 492,
#   'bible-kjv.txt': 257,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 151,
#   'burgess-busterbrown.txt': 85,
#   'carroll-alice.txt': 126,
#   'chesterton-ball.txt': 134,
#   'chesterton-brown.txt': 183,
#   'chesterton-thursday.txt': 98,
#   'edgeworth-parents.txt': 332,
#   'melville-moby_dick.txt': 311,
#   'shakespeare-caesar.txt': 12,
#   'shakespeare-hamlet.txt': 44,
#   'shakespeare-macbeth.txt': 10,
#   'whitman-leaves.txt': 38},
#  'little': {'austen-emma.txt': 354,
#   'austen-persuasion.txt': 175,
#   'austen-sense.txt': 158,
#   'bible-kjv.txt': 238,
#   'blake-poems.txt': 26,
#   'bryant-stories.txt': 532,
#   'burgess-busterbrown.txt': 92,
#   'carroll-alice.txt': 125,
#   'chesterton-ball.txt': 129,
#   'chesterton-brown.txt': 146,
#   'chesterton-thursday.txt': 82,
#   'edgeworth-parents.txt': 400,
#   'melville-moby_dick.txt': 247,
#   'milton-paradise.txt': 8,
#   'shakespeare-caesar.txt': 5,
#   'shakespeare-hamlet.txt': 12,
#   'shakespeare-macbeth.txt': 6,
#   'whitman-leaves.txt': 90},
#  'distress': {'austen-emma.txt': 19,
#   'austen-persuasion.txt': 15,
#   'austen-sense.txt': 26,
#   'bible-kjv.txt': 32,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 3,
#   'chesterton-ball.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 5,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 3,
#   'whitman-leaves.txt': 1},
#  'or': {'austen-emma.txt': 490,
#   'austen-persuasion.txt': 274,
#   'austen-sense.txt': 353,
#   'bible-kjv.txt': 1068,
#   'blake-poems.txt': 6,
#   'bryant-stories.txt': 59,
#   'burgess-busterbrown.txt': 38,
#   'carroll-alice.txt': 76,
#   'chesterton-ball.txt': 381,
#   'chesterton-brown.txt': 287,
#   'chesterton-thursday.txt': 158,
#   'edgeworth-parents.txt': 406,
#   'melville-moby_dick.txt': 697,
#   'milton-paradise.txt': 578,
#   'shakespeare-caesar.txt': 37,
#   'shakespeare-hamlet.txt': 73,
#   'shakespeare-macbeth.txt': 25,
#   'whitman-leaves.txt': 895},
#  'vex': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 14,
#   'edgeworth-parents.txt': 4,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 1},
#  'her': {'austen-emma.txt': 2381,
#   'austen-persuasion.txt': 1159,
#   'austen-sense.txt': 2436,
#   'bible-kjv.txt': 1977,
#   'blake-poems.txt': 32,
#   'bryant-stories.txt': 284,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 243,
#   'chesterton-ball.txt': 108,
#   'chesterton-brown.txt': 118,
#   'chesterton-thursday.txt': 9,
#   'edgeworth-parents.txt': 1486,
#   'melville-moby_dick.txt': 329,
#   'milton-paradise.txt': 275,
#   'shakespeare-caesar.txt': 11,
#   'shakespeare-hamlet.txt': 90,
#   'shakespeare-macbeth.txt': 40,
#   'whitman-leaves.txt': 174},
#  '.': {'austen-emma.txt': 6928,
#   'austen-persuasion.txt': 2741,
#   'austen-sense.txt': 3975,
#   'bible-kjv.txt': 26160,
#   'blake-poems.txt': 201,
#   'bryant-stories.txt': 1817,
#   'burgess-busterbrown.txt': 823,
#   'carroll-alice.txt': 764,
#   'chesterton-ball.txt': 3589,
#   'chesterton-brown.txt': 2784,
#   'chesterton-thursday.txt': 2717,
#   'edgeworth-parents.txt': 6945,
#   'melville-moby_dick.txt': 6862,
#   'milton-paradise.txt': 1254,
#   'shakespeare-caesar.txt': 1296,
#   'shakespeare-hamlet.txt': 1886,
#   'shakespeare-macbeth.txt': 1235,
#   'whitman-leaves.txt': 1769},
#  'She': {'austen-emma.txt': 562,
#   'austen-persuasion.txt': 327,
#   'austen-sense.txt': 258,
#   'bible-kjv.txt': 53,
#   'blake-poems.txt': 8,
#   'bryant-stories.txt': 49,
#   'carroll-alice.txt': 39,
#   'chesterton-ball.txt': 24,
#   'chesterton-brown.txt': 28,
#   'chesterton-thursday.txt': 2,
#   'edgeworth-parents.txt': 177,
#   'melville-moby_dick.txt': 15,
#   'milton-paradise.txt': 23,
#   'shakespeare-caesar.txt': 2,
#   'shakespeare-hamlet.txt': 10,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 32},
#  'was': {'austen-emma.txt': 2385,
#   'austen-persuasion.txt': 1330,
#   'austen-sense.txt': 1846,
#   'bible-kjv.txt': 4515,
#   'blake-poems.txt': 30,
#   'bryant-stories.txt': 706,
#   'burgess-busterbrown.txt': 274,
#   'carroll-alice.txt': 352,
#   'chesterton-ball.txt': 922,
#   'chesterton-brown.txt': 1141,
#   'chesterton-thursday.txt': 716,
#   'edgeworth-parents.txt': 2181,
#   'melville-moby_dick.txt': 1632,
#   'milton-paradise.txt': 177,
#   'shakespeare-caesar.txt': 64,
#   'shakespeare-hamlet.txt': 77,
#   'shakespeare-macbeth.txt': 35,
#   'whitman-leaves.txt': 175},
#  'youngest': {'austen-emma.txt': 4,
#   'austen-persuasion.txt': 6,
#   'austen-sense.txt': 4,
#   'bible-kjv.txt': 18,
#   'blake-poems.txt': 1,
#   'chesterton-ball.txt': 1,
#   'edgeworth-parents.txt': 3,
#   'melville-moby_dick.txt': 1,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 3},
#  'two': {'austen-emma.txt': 171,
#   'austen-persuasion.txt': 112,
#   'austen-sense.txt': 145,
#   'bible-kjv.txt': 823,
#   'blake-poems.txt': 4,
#   'bryant-stories.txt': 61,
#   'burgess-busterbrown.txt': 12,
#   'carroll-alice.txt': 32,
#   'chesterton-ball.txt': 170,
#   'chesterton-brown.txt': 116,
#   'chesterton-thursday.txt': 71,
#   'edgeworth-parents.txt': 131,
#   'melville-moby_dick.txt': 285,
#   'milton-paradise.txt': 39,
#   'shakespeare-caesar.txt': 8,
#   'shakespeare-hamlet.txt': 21,
#   'shakespeare-macbeth.txt': 9,
#   'whitman-leaves.txt': 58},
#  'daughters': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 10,
#   'austen-sense.txt': 27,
#   'bible-kjv.txt': 251,
#   'blake-poems.txt': 1,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 4,
#   'milton-paradise.txt': 4,
#   'whitman-leaves.txt': 13},
#  'most': {'austen-emma.txt': 243,
#   'austen-persuasion.txt': 122,
#   'austen-sense.txt': 152,
#   'bible-kjv.txt': 131,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 24,
#   'burgess-busterbrown.txt': 14,
#   'carroll-alice.txt': 8,
#   'chesterton-ball.txt': 61,
#   'chesterton-brown.txt': 70,
#   'chesterton-thursday.txt': 40,
#   'edgeworth-parents.txt': 117,
#   'melville-moby_dick.txt': 277,
#   'milton-paradise.txt': 34,
#   'shakespeare-caesar.txt': 19,
#   'shakespeare-hamlet.txt': 65,
#   'shakespeare-macbeth.txt': 21,
#   'whitman-leaves.txt': 56},
#  'affectionate': {'austen-emma.txt': 9,
#   'austen-persuasion.txt': 3,
#   'austen-sense.txt': 22,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 8,
#   'melville-moby_dick.txt': 4,
#   'whitman-leaves.txt': 7},
#  'indulgent': {'austen-emma.txt': 2,
#   'austen-sense.txt': 3,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 2,
#   'milton-paradise.txt': 2,
#   'whitman-leaves.txt': 1},
#  'father': {'austen-emma.txt': 207,
#   'austen-persuasion.txt': 117,
#   'austen-sense.txt': 30,
#   'bible-kjv.txt': 854,
#   'blake-poems.txt': 19,
#   'bryant-stories.txt': 57,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 13,
#   'chesterton-brown.txt': 24,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 276,
#   'melville-moby_dick.txt': 16,
#   'milton-paradise.txt': 12,
#   'shakespeare-hamlet.txt': 4,
#   'whitman-leaves.txt': 38},
#  'consequence': {'austen-emma.txt': 27,
#   'austen-persuasion.txt': 33,
#   'austen-sense.txt': 19,
#   'bryant-stories.txt': 1,
#   'chesterton-ball.txt': 4,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 31,
#   'melville-moby_dick.txt': 7,
#   'milton-paradise.txt': 2,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 4,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 1},
#  'sister': {'austen-emma.txt': 33,
#   'austen-persuasion.txt': 82,
#   'austen-sense.txt': 282,
#   'bible-kjv.txt': 116,
#   'bryant-stories.txt': 5,
#   'carroll-alice.txt': 9,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 44,
#   'melville-moby_dick.txt': 5,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 9},
#  "'": {'austen-emma.txt': 1007,
#   'austen-persuasion.txt': 525,
#   'austen-sense.txt': 883,
#   'bible-kjv.txt': 2011,
#   'blake-poems.txt': 104,
#   'bryant-stories.txt': 457,
#   'burgess-busterbrown.txt': 401,
#   'carroll-alice.txt': 1731,
#   'chesterton-ball.txt': 650,
#   'chesterton-brown.txt': 924,
#   'chesterton-thursday.txt': 496,
#   'edgeworth-parents.txt': 3293,
#   'melville-moby_dick.txt': 2684,
#   'milton-paradise.txt': 595,
#   'shakespeare-caesar.txt': 384,
#   'shakespeare-hamlet.txt': 729,
#   'shakespeare-macbeth.txt': 637,
#   'whitman-leaves.txt': 2362},
#  's': {'austen-emma.txt': 933,
#   'austen-persuasion.txt': 485,
#   'austen-sense.txt': 700,
#   'bible-kjv.txt': 1790,
#   'blake-poems.txt': 43,
#   'bryant-stories.txt': 196,
#   'burgess-busterbrown.txt': 151,
#   'carroll-alice.txt': 195,
#   'chesterton-ball.txt': 309,
#   'chesterton-brown.txt': 438,
#   'chesterton-thursday.txt': 224,
#   'edgeworth-parents.txt': 1429,
#   'melville-moby_dick.txt': 1739,
#   'milton-paradise.txt': 262,
#   'shakespeare-caesar.txt': 48,
#   'shakespeare-hamlet.txt': 122,
#   'shakespeare-macbeth.txt': 131,
#   'whitman-leaves.txt': 597},
#  'marriage': {'austen-emma.txt': 34,
#   'austen-persuasion.txt': 27,
#   'austen-sense.txt': 44,
#   'bible-kjv.txt': 18,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 1,
#   'chesterton-thursday.txt': 4,
#   'melville-moby_dick.txt': 2,
#   'milton-paradise.txt': 3,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 7},
#  'been': {'austen-emma.txt': 759,
#   'austen-persuasion.txt': 496,
#   'austen-sense.txt': 440,
#   'bible-kjv.txt': 331,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 41,
#   'burgess-busterbrown.txt': 44,
#   'carroll-alice.txt': 38,
#   'chesterton-ball.txt': 143,
#   'chesterton-brown.txt': 150,
#   'chesterton-thursday.txt': 117,
#   'edgeworth-parents.txt': 334,
#   'melville-moby_dick.txt': 415,
#   'milton-paradise.txt': 32,
#   'shakespeare-hamlet.txt': 3,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 60},
#  'mistress': {'austen-emma.txt': 11,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 12,
#   'bible-kjv.txt': 9,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 2,
#   'edgeworth-parents.txt': 83,
#   'melville-moby_dick.txt': 1,
#   'whitman-leaves.txt': 11},
#  'his': {'austen-emma.txt': 1088,
#   'austen-persuasion.txt': 625,
#   'austen-sense.txt': 941,
#   'bible-kjv.txt': 8385,
#   'blake-poems.txt': 49,
#   'bryant-stories.txt': 531,
#   'burgess-busterbrown.txt': 177,
#   'carroll-alice.txt': 94,
#   'chesterton-ball.txt': 880,
#   'chesterton-brown.txt': 907,
#   'chesterton-thursday.txt': 765,
#   'edgeworth-parents.txt': 1798,
#   'melville-moby_dick.txt': 2459,
#   'milton-paradise.txt': 986,
#   'shakespeare-caesar.txt': 150,
#   'shakespeare-hamlet.txt': 266,
#   'shakespeare-macbeth.txt': 129,
#   'whitman-leaves.txt': 355},
#  'house': {'austen-emma.txt': 95,
#   'austen-persuasion.txt': 78,
#   'austen-sense.txt': 159,
#   'bible-kjv.txt': 2023,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 45,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 18,
#   'chesterton-ball.txt': 29,
#   'chesterton-brown.txt': 80,
#   'chesterton-thursday.txt': 21,
#   'edgeworth-parents.txt': 158,
#   'melville-moby_dick.txt': 43,
#   'milton-paradise.txt': 9,
#   'shakespeare-caesar.txt': 12,
#   'shakespeare-hamlet.txt': 3,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 70},
#  'from': {'austen-emma.txt': 535,
#   'austen-persuasion.txt': 290,
#   'austen-sense.txt': 527,
#   'bible-kjv.txt': 3579,
#   'blake-poems.txt': 28,
#   'bryant-stories.txt': 153,
#   'burgess-busterbrown.txt': 46,
#   'carroll-alice.txt': 34,
#   'chesterton-ball.txt': 239,
#   'chesterton-brown.txt': 229,
#   'chesterton-thursday.txt': 146,
#   'edgeworth-parents.txt': 474,
#   'melville-moby_dick.txt': 1052,
#   'milton-paradise.txt': 543,
#   'shakespeare-caesar.txt': 46,
#   'shakespeare-hamlet.txt': 80,
#   'shakespeare-macbeth.txt': 47,
#   'whitman-leaves.txt': 599},
#  'early': {'austen-emma.txt': 40,
#   'austen-persuasion.txt': 26,
#   'austen-sense.txt': 19,
#   'bible-kjv.txt': 86,
#   'bryant-stories.txt': 9,
#   'burgess-busterbrown.txt': 8,
#   'chesterton-ball.txt': 7,
#   'chesterton-brown.txt': 7,
#   'chesterton-thursday.txt': 12,
#   'edgeworth-parents.txt': 24,
#   'melville-moby_dick.txt': 11,
#   'milton-paradise.txt': 3,
#   'shakespeare-caesar.txt': 1,
#   'whitman-leaves.txt': 24},
#  'period': {'austen-emma.txt': 18,
#   'austen-persuasion.txt': 15,
#   'austen-sense.txt': 7,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 1,
#   'melville-moby_dick.txt': 18,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 2},
#  'Her': {'austen-emma.txt': 88,
#   'austen-persuasion.txt': 45,
#   'austen-sense.txt': 86,
#   'bible-kjv.txt': 18,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 7,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 4,
#   'edgeworth-parents.txt': 37,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 50,
#   'shakespeare-hamlet.txt': 5,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 12},
#  'mother': {'austen-emma.txt': 72,
#   'austen-persuasion.txt': 42,
#   'austen-sense.txt': 258,
#   'bible-kjv.txt': 319,
#   'blake-poems.txt': 19,
#   'bryant-stories.txt': 83,
#   'burgess-busterbrown.txt': 2,
#   'chesterton-ball.txt': 9,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 6,
#   'edgeworth-parents.txt': 200,
#   'melville-moby_dick.txt': 17,
#   'milton-paradise.txt': 16,
#   'shakespeare-hamlet.txt': 3,
#   'whitman-leaves.txt': 75},
#  'died': {'austen-emma.txt': 4,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 8,
#   'bible-kjv.txt': 200,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 13,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 6,
#   'chesterton-brown.txt': 16,
#   'chesterton-thursday.txt': 5,
#   'edgeworth-parents.txt': 7,
#   'melville-moby_dick.txt': 20,
#   'milton-paradise.txt': 2,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 7},
#  'too': {'austen-emma.txt': 253,
#   'austen-persuasion.txt': 127,
#   'austen-sense.txt': 188,
#   'bible-kjv.txt': 51,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 50,
#   'burgess-busterbrown.txt': 34,
#   'carroll-alice.txt': 25,
#   'chesterton-ball.txt': 46,
#   'chesterton-brown.txt': 52,
#   'chesterton-thursday.txt': 57,
#   'edgeworth-parents.txt': 142,
#   'melville-moby_dick.txt': 184,
#   'milton-paradise.txt': 30,
#   'shakespeare-caesar.txt': 30,
#   'shakespeare-hamlet.txt': 55,
#   'shakespeare-macbeth.txt': 30,
#   'whitman-leaves.txt': 103},
#  'long': {'austen-emma.txt': 144,
#   'austen-persuasion.txt': 95,
#   'austen-sense.txt': 100,
#   'bible-kjv.txt': 211,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 57,
#   'burgess-busterbrown.txt': 22,
#   'carroll-alice.txt': 31,
#   'chesterton-ball.txt': 99,
#   'chesterton-brown.txt': 93,
#   'chesterton-thursday.txt': 75,
#   'edgeworth-parents.txt': 123,
#   'melville-moby_dick.txt': 318,
#   'milton-paradise.txt': 72,
#   'shakespeare-caesar.txt': 6,
#   'shakespeare-hamlet.txt': 15,
#   'shakespeare-macbeth.txt': 4,
#   'whitman-leaves.txt': 224},
#  'ago': {'austen-emma.txt': 32,
#   'austen-persuasion.txt': 16,
#   'austen-sense.txt': 15,
#   'bible-kjv.txt': 13,
#   'bryant-stories.txt': 11,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 9,
#   'chesterton-brown.txt': 12,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 30,
#   'melville-moby_dick.txt': 36,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 8},
#  'for': {'austen-emma.txt': 1321,
#   'austen-persuasion.txt': 695,
#   'austen-sense.txt': 1234,
#   'bible-kjv.txt': 7228,
#   'blake-poems.txt': 20,
#   'bryant-stories.txt': 322,
#   'burgess-busterbrown.txt': 97,
#   'carroll-alice.txt': 140,
#   'chesterton-ball.txt': 414,
#   'chesterton-brown.txt': 387,
#   'chesterton-thursday.txt': 279,
#   'edgeworth-parents.txt': 1788,
#   'melville-moby_dick.txt': 1414,
#   'milton-paradise.txt': 327,
#   'shakespeare-caesar.txt': 118,
#   'shakespeare-hamlet.txt': 169,
#   'shakespeare-macbeth.txt': 82,
#   'whitman-leaves.txt': 825},
#  'have': {'austen-emma.txt': 1301,
#   'austen-persuasion.txt': 583,
#   'austen-sense.txt': 807,
#   'bible-kjv.txt': 3843,
#   'blake-poems.txt': 17,
#   'bryant-stories.txt': 149,
#   'burgess-busterbrown.txt': 53,
#   'carroll-alice.txt': 73,
#   'chesterton-ball.txt': 370,
#   'chesterton-brown.txt': 283,
#   'chesterton-thursday.txt': 247,
#   'edgeworth-parents.txt': 956,
#   'melville-moby_dick.txt': 760,
#   'milton-paradise.txt': 138,
#   'whitman-leaves.txt': 320},
#  'more': {'austen-emma.txt': 464,
#   'austen-persuasion.txt': 269,
#   'austen-sense.txt': 406,
#   'bible-kjv.txt': 685,
#   'blake-poems.txt': 9,
#   'bryant-stories.txt': 100,
#   'burgess-busterbrown.txt': 40,
#   'carroll-alice.txt': 47,
#   'chesterton-ball.txt': 171,
#   'chesterton-brown.txt': 226,
#   'chesterton-thursday.txt': 110,
#   'edgeworth-parents.txt': 327,
#   'melville-moby_dick.txt': 501,
#   'milton-paradise.txt': 219,
#   'shakespeare-caesar.txt': 32,
#   'shakespeare-hamlet.txt': 83,
#   'shakespeare-macbeth.txt': 45,
#   'whitman-leaves.txt': 244},
#  'than': {'austen-emma.txt': 415,
#   'austen-persuasion.txt': 243,
#   'austen-sense.txt': 360,
#   'bible-kjv.txt': 482,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 60,
#   'burgess-busterbrown.txt': 34,
#   'carroll-alice.txt': 23,
#   'chesterton-ball.txt': 133,
#   'chesterton-brown.txt': 161,
#   'chesterton-thursday.txt': 82,
#   'edgeworth-parents.txt': 237,
#   'melville-moby_dick.txt': 309,
#   'milton-paradise.txt': 111,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 219},
#  'an': {'austen-emma.txt': 452,
#   'austen-persuasion.txt': 238,
#   'austen-sense.txt': 346,
#   'bible-kjv.txt': 1673,
#   'blake-poems.txt': 20,
#   'bryant-stories.txt': 48,
#   'burgess-busterbrown.txt': 10,
#   'carroll-alice.txt': 52,
#   'chesterton-ball.txt': 310,
#   'chesterton-brown.txt': 236,
#   'chesterton-thursday.txt': 232,
#   'edgeworth-parents.txt': 287,
#   'melville-moby_dick.txt': 582,
#   'milton-paradise.txt': 21,
#   'shakespeare-caesar.txt': 31,
#   'shakespeare-hamlet.txt': 48,
#   'shakespeare-macbeth.txt': 26,
#   'whitman-leaves.txt': 118},
#  'indistinct': {'austen-emma.txt': 1,
#   'austen-sense.txt': 1,
#   'chesterton-ball.txt': 2},
#  'remembrance': {'austen-emma.txt': 8,
#   'austen-persuasion.txt': 6,
#   'austen-sense.txt': 11,
#   'bible-kjv.txt': 51,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 2,
#   'milton-paradise.txt': 3,
#   'shakespeare-hamlet.txt': 3,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 1},
#  'caresses': {'austen-emma.txt': 1,
#   'austen-sense.txt': 1,
#   'edgeworth-parents.txt': 2,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 2},
#  'place': {'austen-emma.txt': 92,
#   'austen-persuasion.txt': 50,
#   'austen-sense.txt': 87,
#   'bible-kjv.txt': 716,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 30,
#   'burgess-busterbrown.txt': 15,
#   'carroll-alice.txt': 8,
#   'chesterton-ball.txt': 67,
#   'chesterton-brown.txt': 67,
#   'chesterton-thursday.txt': 39,
#   'edgeworth-parents.txt': 66,
#   'melville-moby_dick.txt': 116,
#   'milton-paradise.txt': 85,
#   'shakespeare-caesar.txt': 18,
#   'shakespeare-hamlet.txt': 5,
#   'shakespeare-macbeth.txt': 11,
#   'whitman-leaves.txt': 71},
#  'supplied': {'austen-emma.txt': 5,
#   'austen-persuasion.txt': 5,
#   'austen-sense.txt': 3,
#   'bible-kjv.txt': 2,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 5,
#   'melville-moby_dick.txt': 10,
#   'whitman-leaves.txt': 3},
#  'excellent': {'austen-emma.txt': 33,
#   'austen-persuasion.txt': 21,
#   'austen-sense.txt': 11,
#   'bible-kjv.txt': 33,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 5,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 29,
#   'melville-moby_dick.txt': 11,
#   'milton-paradise.txt': 2,
#   'shakespeare-hamlet.txt': 9,
#   'whitman-leaves.txt': 4},
#  'woman': {'austen-emma.txt': 129,
#   'austen-persuasion.txt': 67,
#   'austen-sense.txt': 68,
#   'bible-kjv.txt': 355,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 26,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 19,
#   'chesterton-brown.txt': 30,
#   'chesterton-thursday.txt': 8,
#   'edgeworth-parents.txt': 103,
#   'melville-moby_dick.txt': 10,
#   'milton-paradise.txt': 6,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 6,
#   'shakespeare-macbeth.txt': 7,
#   'whitman-leaves.txt': 94},
#  'as': {'austen-emma.txt': 1387,
#   'austen-persuasion.txt': 787,
#   'austen-sense.txt': 1179,
#   'bible-kjv.txt': 3261,
#   'blake-poems.txt': 14,
#   'bryant-stories.txt': 298,
#   'burgess-busterbrown.txt': 160,
#   'carroll-alice.txt': 246,
#   'chesterton-ball.txt': 646,
#   'chesterton-brown.txt': 585,
#   'chesterton-thursday.txt': 456,
#   'edgeworth-parents.txt': 1332,
#   'melville-moby_dick.txt': 1620,
#   'milton-paradise.txt': 416,
#   'shakespeare-caesar.txt': 100,
#   'shakespeare-hamlet.txt': 142,
#   'shakespeare-macbeth.txt': 55,
#   'whitman-leaves.txt': 651},
#  'governess': {'austen-emma.txt': 9,
#   'austen-persuasion.txt': 2,
#   'edgeworth-parents.txt': 6},
#  'who': {'austen-emma.txt': 281,
#   'austen-persuasion.txt': 186,
#   'austen-sense.txt': 260,
#   'bible-kjv.txt': 690,
#   'blake-poems.txt': 12,
#   'bryant-stories.txt': 104,
#   'burgess-busterbrown.txt': 49,
#   'carroll-alice.txt': 48,
#   'chesterton-ball.txt': 188,
#   'chesterton-brown.txt': 175,
#   'chesterton-thursday.txt': 167,
#   'edgeworth-parents.txt': 674,
#   'melville-moby_dick.txt': 319,
#   'milton-paradise.txt': 244,
#   'shakespeare-caesar.txt': 10,
#   'shakespeare-hamlet.txt': 18,
#   'shakespeare-macbeth.txt': 23,
#   'whitman-leaves.txt': 157},
#  'fallen': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 8,
#   'austen-sense.txt': 2,
#   'bible-kjv.txt': 79,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 1,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 4,
#   'chesterton-ball.txt': 22,
#   'chesterton-brown.txt': 17,
#   'chesterton-thursday.txt': 15,
#   'edgeworth-parents.txt': 7,
#   'melville-moby_dick.txt': 4,
#   'milton-paradise.txt': 21,
#   'whitman-leaves.txt': 14},
#  'short': {'austen-emma.txt': 67,
#   'austen-persuasion.txt': 47,
#   'austen-sense.txt': 56,
#   'bible-kjv.txt': 13,
#   'bryant-stories.txt': 4,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 4,
#   'chesterton-ball.txt': 24,
#   'chesterton-brown.txt': 34,
#   'chesterton-thursday.txt': 17,
#   'edgeworth-parents.txt': 36,
#   'melville-moby_dick.txt': 59,
#   'milton-paradise.txt': 14,
#   'shakespeare-hamlet.txt': 5,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 11},
#  'affection': {'austen-emma.txt': 50,
#   'austen-persuasion.txt': 9,
#   'austen-sense.txt': 79,
#   'bible-kjv.txt': 6,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 3,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 2,
#   'whitman-leaves.txt': 7},
#  'Sixteen': {'austen-emma.txt': 2,
#   'bible-kjv.txt': 2,
#   'melville-moby_dick.txt': 1},
#  'Miss': {'austen-emma.txt': 592,
#   'austen-persuasion.txt': 123,
#   'austen-sense.txt': 208,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 32,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 166},
#  'Taylor': {'austen-emma.txt': 48,
#   'austen-sense.txt': 2,
#   'shakespeare-macbeth.txt': 2},
#  'Mr': {'austen-emma.txt': 1153,
#   'austen-persuasion.txt': 256,
#   'austen-sense.txt': 178,
#   'bryant-stories.txt': 12,
#   'burgess-busterbrown.txt': 18,
#   'chesterton-ball.txt': 87,
#   'chesterton-brown.txt': 99,
#   'chesterton-thursday.txt': 26,
#   'edgeworth-parents.txt': 458,
#   'melville-moby_dick.txt': 63},
#  'family': {'austen-emma.txt': 77,
#   'austen-persuasion.txt': 79,
#   'austen-sense.txt': 83,
#   'bible-kjv.txt': 123,
#   'bryant-stories.txt': 7,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 47,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 34,
#   'melville-moby_dick.txt': 12,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 5},
#  'less': {'austen-emma.txt': 68,
#   'austen-persuasion.txt': 30,
#   'austen-sense.txt': 96,
#   'bible-kjv.txt': 27,
#   'bryant-stories.txt': 5,
#   'burgess-busterbrown.txt': 2,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 23,
#   'chesterton-brown.txt': 26,
#   'chesterton-thursday.txt': 8,
#   'edgeworth-parents.txt': 23,
#   'melville-moby_dick.txt': 51,
#   'milton-paradise.txt': 74,
#   'whitman-leaves.txt': 35},
#  'friend': {'austen-emma.txt': 177,
#   'austen-persuasion.txt': 83,
#   'austen-sense.txt': 55,
#   'bible-kjv.txt': 47,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 25,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 16,
#   'chesterton-brown.txt': 56,
#   'chesterton-thursday.txt': 28,
#   'edgeworth-parents.txt': 127,
#   'melville-moby_dick.txt': 25,
#   'milton-paradise.txt': 5,
#   'shakespeare-caesar.txt': 5,
#   'shakespeare-hamlet.txt': 4,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 43},
#  'fond': {'austen-emma.txt': 39,
#   'austen-persuasion.txt': 11,
#   'austen-sense.txt': 21,
#   'bryant-stories.txt': 4,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 4,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 7,
#   'edgeworth-parents.txt': 44,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 4,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 2,
#   'whitman-leaves.txt': 3},
#  'both': {'austen-emma.txt': 83,
#   'austen-persuasion.txt': 38,
#   'austen-sense.txt': 92,
#   'bible-kjv.txt': 352,
#   'blake-poems.txt': 6,
#   'bryant-stories.txt': 6,
#   'carroll-alice.txt': 14,
#   'chesterton-ball.txt': 41,
#   'chesterton-brown.txt': 46,
#   'chesterton-thursday.txt': 15,
#   'edgeworth-parents.txt': 41,
#   'melville-moby_dick.txt': 118,
#   'milton-paradise.txt': 83,
#   'shakespeare-caesar.txt': 6,
#   'shakespeare-hamlet.txt': 22,
#   'shakespeare-macbeth.txt': 14,
#   'whitman-leaves.txt': 11},
#  'but': {'austen-emma.txt': 1148,
#   'austen-persuasion.txt': 553,
#   'austen-sense.txt': 597,
#   'bible-kjv.txt': 2434,
#   'blake-poems.txt': 14,
#   'bryant-stories.txt': 161,
#   'burgess-busterbrown.txt': 56,
#   'carroll-alice.txt': 133,
#   'chesterton-ball.txt': 339,
#   'chesterton-brown.txt': 487,
#   'chesterton-thursday.txt': 282,
#   'edgeworth-parents.txt': 1016,
#   'melville-moby_dick.txt': 1113,
#   'milton-paradise.txt': 370,
#   'shakespeare-caesar.txt': 68,
#   'shakespeare-hamlet.txt': 146,
#   'shakespeare-macbeth.txt': 60,
#   'whitman-leaves.txt': 275},
#  'particularly': {'austen-emma.txt': 46,
#   'austen-persuasion.txt': 21,
#   'austen-sense.txt': 34,
#   'bible-kjv.txt': 2,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 5,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 13,
#   'melville-moby_dick.txt': 8},
#  'Between': {'austen-emma.txt': 2,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 2,
#   'bryant-stories.txt': 2,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 2,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 2,
#   'milton-paradise.txt': 4},
#  '_them_': {'austen-emma.txt': 4},
#  'it': {'austen-emma.txt': 2128,
#   'austen-persuasion.txt': 857,
#   'austen-sense.txt': 1568,
#   'bible-kjv.txt': 5891,
#   'blake-poems.txt': 26,
#   'bryant-stories.txt': 515,
#   'burgess-busterbrown.txt': 239,
#   'carroll-alice.txt': 527,
#   'chesterton-ball.txt': 938,
#   'chesterton-brown.txt': 796,
#   'chesterton-thursday.txt': 565,
#   'edgeworth-parents.txt': 2008,
#   'melville-moby_dick.txt': 2209,
#   'milton-paradise.txt': 127,
#   'shakespeare-caesar.txt': 166,
#   'shakespeare-hamlet.txt': 354,
#   'shakespeare-macbeth.txt': 138,
#   'whitman-leaves.txt': 682},
#  'intimacy': {'austen-emma.txt': 20,
#   'austen-persuasion.txt': 9,
#   'austen-sense.txt': 11,
#   'chesterton-brown.txt': 2,
#   'edgeworth-parents.txt': 3,
#   'melville-moby_dick.txt': 1},
#  'sisters': {'austen-emma.txt': 12,
#   'austen-persuasion.txt': 17,
#   'austen-sense.txt': 48,
#   'bible-kjv.txt': 19,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 5,
#   'carroll-alice.txt': 2,
#   'edgeworth-parents.txt': 23,
#   'whitman-leaves.txt': 24},
#  'Even': {'austen-emma.txt': 10,
#   'austen-persuasion.txt': 4,
#   'austen-sense.txt': 4,
#   'bible-kjv.txt': 96,
#   'bryant-stories.txt': 4,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 16,
#   'chesterton-brown.txt': 8,
#   'chesterton-thursday.txt': 10,
#   'edgeworth-parents.txt': 7,
#   'melville-moby_dick.txt': 10,
#   'milton-paradise.txt': 6,
#   'whitman-leaves.txt': 6},
#  'before': {'austen-emma.txt': 243,
#   'austen-persuasion.txt': 113,
#   'austen-sense.txt': 198,
#   'bible-kjv.txt': 1775,
#   'blake-poems.txt': 7,
#   'bryant-stories.txt': 54,
#   'burgess-busterbrown.txt': 18,
#   'carroll-alice.txt': 36,
#   'chesterton-ball.txt': 77,
#   'chesterton-brown.txt': 82,
#   'chesterton-thursday.txt': 54,
#   'edgeworth-parents.txt': 202,
#   'melville-moby_dick.txt': 293,
#   'milton-paradise.txt': 45,
#   'shakespeare-caesar.txt': 10,
#   'shakespeare-hamlet.txt': 13,
#   'shakespeare-macbeth.txt': 19,
#   'whitman-leaves.txt': 96},
#  'ceased': {'austen-emma.txt': 6,
#   'austen-persuasion.txt': 8,
#   'austen-sense.txt': 10,
#   'bible-kjv.txt': 33,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 3,
#   'milton-paradise.txt': 12,
#   'whitman-leaves.txt': 1},
#  'hold': {'austen-emma.txt': 14,
#   'austen-persuasion.txt': 8,
#   'austen-sense.txt': 12,
#   'bible-kjv.txt': 174,
#   'bryant-stories.txt': 22,
#   'burgess-busterbrown.txt': 2,
#   'carroll-alice.txt': 6,
#   'chesterton-ball.txt': 14,
#   'chesterton-brown.txt': 14,
#   'chesterton-thursday.txt': 7,
#   'edgeworth-parents.txt': 46,
#   'melville-moby_dick.txt': 89,
#   'milton-paradise.txt': 21,
#   'shakespeare-caesar.txt': 10,
#   'shakespeare-hamlet.txt': 21,
#   'shakespeare-macbeth.txt': 9,
#   'whitman-leaves.txt': 38},
#  'nominal': {'austen-emma.txt': 1,
#   'austen-sense.txt': 1,
#   'melville-moby_dick.txt': 2},
#  'office': {'austen-emma.txt': 16,
#   'austen-persuasion.txt': 5,
#   'austen-sense.txt': 6,
#   'bible-kjv.txt': 46,
#   'bryant-stories.txt': 2,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 4,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 9,
#   'whitman-leaves.txt': 3},
#  'mildness': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 3,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'melville-moby_dick.txt': 5,
#   'milton-paradise.txt': 2},
#  'temper': {'austen-emma.txt': 36,
#   'austen-persuasion.txt': 12,
#   'austen-sense.txt': 21,
#   'bible-kjv.txt': 1,
#   'bryant-stories.txt': 2,
#   'burgess-busterbrown.txt': 10,
#   'carroll-alice.txt': 5,
#   'chesterton-ball.txt': 8,
#   'chesterton-brown.txt': 2,
#   'edgeworth-parents.txt': 18,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 9,
#   'shakespeare-caesar.txt': 4,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 3},
#  'hardly': {'austen-emma.txt': 71,
#   'austen-persuasion.txt': 39,
#   'austen-sense.txt': 65,
#   'bible-kjv.txt': 8,
#   'bryant-stories.txt': 6,
#   'burgess-busterbrown.txt': 2,
#   'carroll-alice.txt': 11,
#   'chesterton-ball.txt': 15,
#   'chesterton-brown.txt': 22,
#   'chesterton-thursday.txt': 13,
#   'edgeworth-parents.txt': 8,
#   'melville-moby_dick.txt': 31,
#   'milton-paradise.txt': 1,
#   'shakespeare-hamlet.txt': 1,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 9},
#  'allowed': {'austen-emma.txt': 40,
#   'austen-persuasion.txt': 15,
#   'austen-sense.txt': 17,
#   'bible-kjv.txt': 1,
#   'bryant-stories.txt': 1,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 7,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 8,
#   'melville-moby_dick.txt': 6,
#   'shakespeare-hamlet.txt': 2},
#  'impose': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 1,
#   'edgeworth-parents.txt': 6,
#   'milton-paradise.txt': 3},
#  'any': {'austen-emma.txt': 651,
#   'austen-persuasion.txt': 198,
#   'austen-sense.txt': 389,
#   'bible-kjv.txt': 912,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 43,
#   'burgess-busterbrown.txt': 27,
#   'carroll-alice.txt': 39,
#   'chesterton-ball.txt': 109,
#   'chesterton-brown.txt': 84,
#   'chesterton-thursday.txt': 61,
#   'edgeworth-parents.txt': 229,
# ...
#   'whitman-leaves.txt': 2},
#  'embodied': {'austen-emma.txt': 1,
#   'melville-moby_dick.txt': 1,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 2},
#  'Captain': {'austen-emma.txt': 3,
#   'austen-persuasion.txt': 297,
#   'chesterton-brown.txt': 16,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 11,
#   'melville-moby_dick.txt': 215,
#   'whitman-leaves.txt': 12},
#  'general': {'austen-emma.txt': 64,
#   'austen-persuasion.txt': 34,
#   'austen-sense.txt': 55,
#   'bible-kjv.txt': 2,
#   'carroll-alice.txt': 3,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 2,
#   'chesterton-thursday.txt': 6,
#   'edgeworth-parents.txt': 13,
#   'melville-moby_dick.txt': 65,
#   'milton-paradise.txt': 8,
#   'whitman-leaves.txt': 12},
#  'favourite': {'austen-emma.txt': 23,
#   'austen-persuasion.txt': 8,
#   'austen-sense.txt': 25,
#   'bryant-stories.txt': 2,
#   'carroll-alice.txt': 1,
#   'chesterton-brown.txt': 5,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 35,
#   'melville-moby_dick.txt': 4,
#   'milton-paradise.txt': 1},
#  'military': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 1,
#   'chesterton-ball.txt': 6,
#   'chesterton-brown.txt': 7,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 1,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 3,
#   'whitman-leaves.txt': 1},
#  'introduced': {'austen-emma.txt': 8,
#   'austen-persuasion.txt': 14,
#   'austen-sense.txt': 9,
#   'carroll-alice.txt': 1,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 1,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 1},
#  'Churchill': {'austen-emma.txt': 223, 'edgeworth-parents.txt': 18},
#  'Yorkshire': {'austen-emma.txt': 8,
#   'chesterton-brown.txt': 1,
#   'melville-moby_dick.txt': 1},
#  'fell': {'austen-emma.txt': 10,
#   'austen-persuasion.txt': 9,
#   'austen-sense.txt': 12,
#   'bible-kjv.txt': 243,
#   'bryant-stories.txt': 17,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 6,
#   'chesterton-ball.txt': 43,
#   'chesterton-brown.txt': 27,
#   'chesterton-thursday.txt': 28,
#   'edgeworth-parents.txt': 25,
#   'melville-moby_dick.txt': 36,
#   'milton-paradise.txt': 38,
#   'shakespeare-caesar.txt': 12,
#   'shakespeare-hamlet.txt': 6,
#   'shakespeare-macbeth.txt': 6,
#   'whitman-leaves.txt': 7},
#  'love': {'austen-emma.txt': 117,
#   'austen-persuasion.txt': 42,
#   'austen-sense.txt': 77,
#   'bible-kjv.txt': 304,
#   'blake-poems.txt': 15,
#   'bryant-stories.txt': 13,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 19,
#   'chesterton-brown.txt': 8,
#   'chesterton-thursday.txt': 8,
#   'edgeworth-parents.txt': 83,
#   'melville-moby_dick.txt': 24,
#   'milton-paradise.txt': 91,
#   'whitman-leaves.txt': 259},
#  'surprized': {'austen-emma.txt': 32, 'shakespeare-hamlet.txt': 1},
#  'except': {'austen-emma.txt': 31,
#   'austen-persuasion.txt': 9,
#   'austen-sense.txt': 17,
#   'bible-kjv.txt': 58,
#   'bryant-stories.txt': 11,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 4,
#   'chesterton-ball.txt': 20,
#   'chesterton-brown.txt': 27,
#   'chesterton-thursday.txt': 18,
#   'edgeworth-parents.txt': 17,
#   'melville-moby_dick.txt': 31,
#   'milton-paradise.txt': 7,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 16},
#  'full': {'austen-emma.txt': 44,
#   'austen-persuasion.txt': 30,
#   'austen-sense.txt': 30,
#   'bible-kjv.txt': 259,
#   'bryant-stories.txt': 14,
#   'burgess-busterbrown.txt': 4,
#   'carroll-alice.txt': 6,
#   'chesterton-ball.txt': 35,
#   'chesterton-brown.txt': 22,
#   'chesterton-thursday.txt': 14,
#   'edgeworth-parents.txt': 67,
#   'melville-moby_dick.txt': 121,
#   'milton-paradise.txt': 38,
#   'shakespeare-caesar.txt': 10,
#   'shakespeare-hamlet.txt': 9,
#   'shakespeare-macbeth.txt': 11,
#   'whitman-leaves.txt': 81},
#  'pride': {'austen-emma.txt': 18,
#   'austen-persuasion.txt': 17,
#   'austen-sense.txt': 8,
#   'bible-kjv.txt': 48,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 4,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 7,
#   'edgeworth-parents.txt': 11,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 17,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 21},
#  'importance': {'austen-emma.txt': 12,
#   'austen-persuasion.txt': 11,
#   'austen-sense.txt': 15,
#   'bryant-stories.txt': 1,
#   'chesterton-ball.txt': 6,
#   'chesterton-brown.txt': 9,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 7,
#   'melville-moby_dick.txt': 6},
#  'connexion': {'austen-emma.txt': 20,
#   'austen-persuasion.txt': 10,
#   'chesterton-ball.txt': 2,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 1},
#  'offend': {'austen-emma.txt': 3,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 6,
#   'bible-kjv.txt': 25,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 2,
#   'edgeworth-parents.txt': 6,
#   'milton-paradise.txt': 5,
#   'shakespeare-hamlet.txt': 1,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 3},
#  'command': {'austen-emma.txt': 21,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 14,
#   'bible-kjv.txt': 96,
#   'bryant-stories.txt': 3,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 6,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 15,
#   'melville-moby_dick.txt': 28,
#   'milton-paradise.txt': 23,
#   'shakespeare-hamlet.txt': 11,
#   'shakespeare-macbeth.txt': 5,
#   'whitman-leaves.txt': 8},
#  'bore': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 3,
#   'austen-sense.txt': 4,
#   'bible-kjv.txt': 3,
#   'blake-poems.txt': 6,
#   'bryant-stories.txt': 4,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 4,
#   'chesterton-thursday.txt': 2,
#   'edgeworth-parents.txt': 5,
#   'melville-moby_dick.txt': 17,
#   'milton-paradise.txt': 6,
#   'shakespeare-hamlet.txt': 4,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 3},
#  'proportion': {'austen-emma.txt': 4,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 4,
#   'bible-kjv.txt': 3,
#   'bryant-stories.txt': 2,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 3,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 2,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 5},
#  'estate': {'austen-emma.txt': 4,
#   'austen-persuasion.txt': 6,
#   'austen-sense.txt': 19,
#   'bible-kjv.txt': 17,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 5,
#   'edgeworth-parents.txt': 5,
#   'melville-moby_dick.txt': 1,
#   'milton-paradise.txt': 1,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 2},
#  'dissuaded': {'austen-emma.txt': 1},
#  'took': {'austen-emma.txt': 47,
#   'austen-persuasion.txt': 19,
#   'austen-sense.txt': 52,
#   'bible-kjv.txt': 749,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 57,
#   'burgess-busterbrown.txt': 10,
#   'carroll-alice.txt': 23,
#   'chesterton-ball.txt': 36,
#   'chesterton-brown.txt': 34,
#   'chesterton-thursday.txt': 39,
#   'edgeworth-parents.txt': 95,
#   'melville-moby_dick.txt': 49,
#   'milton-paradise.txt': 17,
#   'whitman-leaves.txt': 8},
#  'infinite': {'austen-emma.txt': 3,
#   'bible-kjv.txt': 3,
#   'bryant-stories.txt': 1,
#   'chesterton-ball.txt': 2,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 4,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 19,
#   'shakespeare-hamlet.txt': 3,
#   'whitman-leaves.txt': 10},
#  'mortification': {'austen-emma.txt': 11,
#   'austen-persuasion.txt': 5,
#   'austen-sense.txt': 2,
#   'edgeworth-parents.txt': 4},
#  'threw': {'austen-emma.txt': 2,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 3,
#   'bible-kjv.txt': 6,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 10,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 15,
#   'chesterton-thursday.txt': 7,
#   'edgeworth-parents.txt': 35,
#   'melville-moby_dick.txt': 10,
#   'milton-paradise.txt': 7,
#   'shakespeare-caesar.txt': 1,
#   'whitman-leaves.txt': 2},
#  'due': {'austen-emma.txt': 23,
#   'austen-persuasion.txt': 13,
#   'austen-sense.txt': 13,
#   'bible-kjv.txt': 31,
#   'chesterton-ball.txt': 4,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 8,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 27,
#   'shakespeare-hamlet.txt': 1,
#   'shakespeare-macbeth.txt': 3,
#   'whitman-leaves.txt': 10},
#  'decorum': {'austen-emma.txt': 2,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 2,
#   'chesterton-ball.txt': 2,
#   'whitman-leaves.txt': 2},
#  'unsuitable': {'austen-emma.txt': 3, 'austen-sense.txt': 2},
#  'produce': {'austen-emma.txt': 10,
#   'austen-persuasion.txt': 4,
#   'austen-sense.txt': 9,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 11,
#   'melville-moby_dick.txt': 5,
#   'milton-paradise.txt': 3,
#   'whitman-leaves.txt': 4},
#  'ought': {'austen-emma.txt': 94,
#   'austen-persuasion.txt': 52,
#   'austen-sense.txt': 34,
#   'bible-kjv.txt': 95,
#   'bryant-stories.txt': 3,
#   'burgess-busterbrown.txt': 7,
#   'carroll-alice.txt': 14,
#   'chesterton-ball.txt': 24,
#   'chesterton-brown.txt': 6,
#   'chesterton-thursday.txt': 9,
#   'edgeworth-parents.txt': 18,
#   'melville-moby_dick.txt': 8,
#   'milton-paradise.txt': 2,
#   'shakespeare-caesar.txt': 4,
#   'shakespeare-hamlet.txt': 9,
#   'whitman-leaves.txt': 2},
#  'whose': {'austen-emma.txt': 39,
#   'austen-persuasion.txt': 21,
#   'austen-sense.txt': 48,
#   'bible-kjv.txt': 284,
#   'bryant-stories.txt': 2,
#   'burgess-busterbrown.txt': 3,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 35,
#   'chesterton-brown.txt': 17,
#   'chesterton-thursday.txt': 14,
#   'edgeworth-parents.txt': 47,
#   'melville-moby_dick.txt': 86,
#   'milton-paradise.txt': 84,
#   'shakespeare-caesar.txt': 2,
#   'shakespeare-hamlet.txt': 19,
#   'shakespeare-macbeth.txt': 5,
#   'whitman-leaves.txt': 22},
#  'warm': {'austen-emma.txt': 30,
#   'austen-persuasion.txt': 17,
#   'austen-sense.txt': 12,
#   'bible-kjv.txt': 8,
#   'blake-poems.txt': 3,
#   'bryant-stories.txt': 7,
#   'burgess-busterbrown.txt': 1,
#   'chesterton-ball.txt': 3,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 2,
#   'edgeworth-parents.txt': 18,
#   'melville-moby_dick.txt': 24,
#   'milton-paradise.txt': 4,
#   'shakespeare-hamlet.txt': 1,
#   'whitman-leaves.txt': 8},
#  'sweet': {'austen-emma.txt': 22,
#   'austen-persuasion.txt': 7,
#   'austen-sense.txt': 13,
#   'bible-kjv.txt': 108,
#   'blake-poems.txt': 12,
#   'bryant-stories.txt': 23,
#   'burgess-busterbrown.txt': 1,
#   'carroll-alice.txt': 1,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 2,
#   'chesterton-thursday.txt': 2,
#   'edgeworth-parents.txt': 9,
#   'melville-moby_dick.txt': 23,
#   'milton-paradise.txt': 55,
#   'shakespeare-caesar.txt': 3,
#   'shakespeare-hamlet.txt': 19,
#   'shakespeare-macbeth.txt': 2,
#   'whitman-leaves.txt': 75},
#  'return': {'austen-emma.txt': 56,
#   'austen-persuasion.txt': 28,
#   'austen-sense.txt': 42,
#   'bible-kjv.txt': 243,
#   'blake-poems.txt': 3,
#   'chesterton-ball.txt': 6,
#   'chesterton-brown.txt': 6,
#   'chesterton-thursday.txt': 5,
#   'edgeworth-parents.txt': 35,
#   'melville-moby_dick.txt': 13,
#   'milton-paradise.txt': 33,
#   'shakespeare-hamlet.txt': 4,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 57},
#  'goodness': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 4,
#   'austen-sense.txt': 8,
#   'bible-kjv.txt': 51,
#   'bryant-stories.txt': 4,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 2,
#   'edgeworth-parents.txt': 11,
#   'melville-moby_dick.txt': 5,
#   'milton-paradise.txt': 11,
#   'whitman-leaves.txt': 5},
#  'spirit': {'austen-emma.txt': 27,
#   'austen-persuasion.txt': 12,
#   'austen-sense.txt': 17,
#   'bible-kjv.txt': 337,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 2,
#   'burgess-busterbrown.txt': 1,
#   'chesterton-ball.txt': 5,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 3,
#   'edgeworth-parents.txt': 22,
#   'melville-moby_dick.txt': 15,
#   'milton-paradise.txt': 11,
#   'shakespeare-caesar.txt': 4,
#   'shakespeare-hamlet.txt': 4,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 39},
#  'resolution': {'austen-emma.txt': 31,
#   'austen-persuasion.txt': 11,
#   'austen-sense.txt': 26,
#   'chesterton-ball.txt': 2,
#   'edgeworth-parents.txt': 5,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 5,
#   'whitman-leaves.txt': 1},
#  'pursue': {'austen-emma.txt': 1,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 28,
#   'chesterton-thursday.txt': 4,
#   'edgeworth-parents.txt': 2,
#   'melville-moby_dick.txt': 2,
#   'milton-paradise.txt': 5,
#   'shakespeare-hamlet.txt': 2,
#   'whitman-leaves.txt': 2},
#  'refrain': {'austen-emma.txt': 5,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 1,
#   'bible-kjv.txt': 7,
#   'edgeworth-parents.txt': 3,
#   'whitman-leaves.txt': 6},
#  'unreasonable': {'austen-emma.txt': 9,
#   'austen-persuasion.txt': 1,
#   'austen-sense.txt': 2,
#   'bible-kjv.txt': 2,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 1,
#   'edgeworth-parents.txt': 3,
#   'melville-moby_dick.txt': 2},
#  'anger': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 2,
#   'austen-sense.txt': 5,
#   'bible-kjv.txt': 234,
#   'bryant-stories.txt': 1,
#   'burgess-busterbrown.txt': 4,
#   'carroll-alice.txt': 2,
#   'chesterton-ball.txt': 7,
#   'chesterton-brown.txt': 7,
#   'chesterton-thursday.txt': 6,
#   'edgeworth-parents.txt': 11,
#   'melville-moby_dick.txt': 3,
#   'milton-paradise.txt': 12,
#   'shakespeare-hamlet.txt': 1,
#   'shakespeare-macbeth.txt': 2,
#   'whitman-leaves.txt': 3},
#  'missing': {'austen-emma.txt': 3,
#   'austen-persuasion.txt': 1,
#   'bible-kjv.txt': 2,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 3,
#   'melville-moby_dick.txt': 16,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 1},
#  'luxuries': {'austen-emma.txt': 1, 'chesterton-brown.txt': 3},
#  'former': {'austen-emma.txt': 13,
#   'austen-persuasion.txt': 28,
#   'austen-sense.txt': 31,
#   'bible-kjv.txt': 50,
#   'blake-poems.txt': 1,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 3,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 9,
#   'melville-moby_dick.txt': 20,
#   'milton-paradise.txt': 7,
#   'shakespeare-caesar.txt': 1,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 5,
#   'whitman-leaves.txt': 2},
#  'income': {'austen-emma.txt': 10,
#   'austen-persuasion.txt': 5,
#   'austen-sense.txt': 23,
#   'chesterton-brown.txt': 1,
#   'melville-moby_dick.txt': 2,
#   'whitman-leaves.txt': 1},
#  'still': {'austen-emma.txt': 109,
#   'austen-persuasion.txt': 72,
#   'austen-sense.txt': 97,
#   'bible-kjv.txt': 101,
#   'blake-poems.txt': 1,
#   'bryant-stories.txt': 39,
#   'burgess-busterbrown.txt': 15,
#   'carroll-alice.txt': 12,
#   'chesterton-ball.txt': 98,
#   'chesterton-brown.txt': 101,
#   'chesterton-thursday.txt': 72,
#   'edgeworth-parents.txt': 85,
#   'melville-moby_dick.txt': 299,
#   'milton-paradise.txt': 76,
#   'shakespeare-caesar.txt': 11,
#   'shakespeare-hamlet.txt': 14,
#   'shakespeare-macbeth.txt': 17,
#   'whitman-leaves.txt': 60},
#  'comparison': {'austen-emma.txt': 11,
#   'austen-persuasion.txt': 6,
#   'austen-sense.txt': 13,
#   'bible-kjv.txt': 4,
#   'chesterton-ball.txt': 2,
#   'chesterton-brown.txt': 3,
#   'edgeworth-parents.txt': 1,
#   'melville-moby_dick.txt': 6,
#   'milton-paradise.txt': 1,
#   'whitman-leaves.txt': 1},
#  'Enscombe': {'austen-emma.txt': 36},
#  'cease': {'austen-emma.txt': 7,
#   'austen-persuasion.txt': 3,
#   'austen-sense.txt': 5,
#   'bible-kjv.txt': 65,
#   'bryant-stories.txt': 1,
#   'chesterton-ball.txt': 1,
#   'chesterton-brown.txt': 1,
#   'chesterton-thursday.txt': 1,
#   'edgeworth-parents.txt': 1,
#   'melville-moby_dick.txt': 2,
#   'milton-paradise.txt': 4,
#   'shakespeare-hamlet.txt': 2,
#   'shakespeare-macbeth.txt': 1,
#   'whitman-leaves.txt': 16},
#  'once': {'austen-emma.txt': 82,
#   'austen-persuasion.txt': 52,
#   'austen-sense.txt': 72,
#   'bible-kjv.txt': 57,
#   'blake-poems.txt': 2,
#   'bryant-stories.txt': 41,
#   'burgess-busterbrown.txt': 13,
#   'carroll-alice.txt': 31,
#   'chesterton-ball.txt': 49,
#   'chesterton-brown.txt': 49,
#   'chesterton-thursday.txt': 38,
#   'edgeworth-parents.txt': 81,
#   'melville-moby_dick.txt': 144,
#   'milton-paradise.txt': 67,
#   'shakespeare-caesar.txt': 14,
#   'shakespeare-hamlet.txt': 18,
#   'shakespeare-macbeth.txt': 11,
#   'whitman-leaves.txt': 41},
#  ...}

# %% [markdown]
# ## Maximum term frequency for every document

# %%
max_frequency = {}
for book_name in file_names:
    max_frequency[book_name] = 0

for posting_list in inverted_index.values():
    for book_name in posting_list.keys():
        max_frequency[book_name] = max(max_frequency[book_name], posting_list[book_name])

# %%
max_frequency
# Out:
# {'austen-emma.txt': 11454,
#  'austen-persuasion.txt': 6750,
#  'austen-sense.txt': 9397,
#  'bible-kjv.txt': 70509,
#  'blake-poems.txt': 680,
#  'bryant-stories.txt': 3481,
#  'burgess-busterbrown.txt': 823,
#  'carroll-alice.txt': 1993,
#  'chesterton-ball.txt': 4547,
#  'chesterton-brown.txt': 4321,
#  'chesterton-thursday.txt': 3488,
#  'edgeworth-parents.txt': 15219,
#  'melville-moby_dick.txt': 18713,
#  'milton-paradise.txt': 10198,
#  'shakespeare-caesar.txt': 2204,
#  'shakespeare-hamlet.txt': 2892,
#  'shakespeare-macbeth.txt': 1962,
#  'whitman-leaves.txt': 17713}
